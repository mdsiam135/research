# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy pandas scikit-learn
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
#Support Vector Machine (SVM)

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, classification_report
)
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# --- Step 1: Load Dataset ---
df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train2.csv')  # Replace with your dataset

# %%
# --- Step 2: Binning using quantiles ---
labels = ['very low', 'low', 'medium', 'high', 'very high']
df['Production_Label'], bin_edges = pd.qcut(df['Production (M.Ton)'], q=5, labels=labels, retbins=True)

# %%
# --- Display bin ranges ---
print("Label Ranges (Quantiles):")
for i in range(len(bin_edges) - 1):
    print(f"{labels[i].capitalize()}: {bin_edges[i]:.2f} - {bin_edges[i+1]:.2f}")
# Out:
# Label Ranges (Quantiles):
# Very low: 0.00 - 545.38
# Low: 545.38 - 1452.00
# Medium: 1452.00 - 3050.00
# High: 3050.00 - 6447.40
# Very high: 6447.40 - 544979.54

# %%
# --- Label counts ---
print("\nLabel Counts:")
print(df['Production_Label'].value_counts())
# Out:
# Label Counts:
# Production_Label
# low          1025
# very low     1024
# medium       1024
# very high    1024
# high         1023
# Name: count, dtype: int64

# %%
# --- Step 3: Prepare features and encoded labels ---
X = df.drop(columns=['Production (M.Ton)', 'Production_Label'])
y = df['Production_Label']

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# --- Step 4: Split into train/val/test sets ---
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y_encoded, test_size=0.15, stratify=y_encoded, random_state=42
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1765, stratify=y_temp, random_state=42
)  # ≈15% of full data

# %%
# --- Step 5: Define SVM pipeline ---
model = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel='rbf', probability=True, random_state=42))
])

# %%
# --- Step 6: Training with Epochs ---
epochs = 10
best_val_f1 = 0
best_model = None

epoch_history = []  # Store metrics for each epoch

for epoch in range(epochs):
    print(f"\nEpoch {epoch + 1}/{epochs}")
    model.fit(X_train, y_train)
    y_val_pred = model.predict(X_val)

    val_acc = accuracy_score(y_val, y_val_pred)
    val_precision = precision_score(y_val, y_val_pred, average='weighted', zero_division=0)
    val_recall = recall_score(y_val, y_val_pred, average='weighted', zero_division=0)
    val_f1_weighted = f1_score(y_val, y_val_pred, average='weighted', zero_division=0)
    val_f1_macro = f1_score(y_val, y_val_pred, average='macro', zero_division=0)

    print(f"Validation Accuracy: {val_acc:.4f}")
    print(f"Weighted Precision: {val_precision:.4f}, Weighted Recall: {val_recall:.4f}, Weighted F1: {val_f1_weighted:.4f}")
    print(f"Macro F1 Score: {val_f1_macro:.4f}")

    # Save best model
    if val_f1_weighted > best_val_f1:
        best_val_f1 = val_f1_weighted
        best_model = model

    # Store results
    epoch_history.append({
        'Epoch': epoch + 1,
        'Accuracy': val_acc,
        'Precision': val_precision,
        'Recall': val_recall,
        'F1_Weighted': val_f1_weighted,
        'F1_Macro': val_f1_macro
    })
# Out:
# Epoch 1/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 2/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 3/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 4/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 5/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 6/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 7/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 8/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 9/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487
#
# Epoch 10/10
# Validation Accuracy: 0.7503
# Weighted Precision: 0.7504, Weighted Recall: 0.7503, Weighted F1: 0.7489
# Macro F1 Score: 0.7487

# %%
# --- Step 7: Print epoch effects table ---
print("\n--- Epoch-wise Validation Metrics ---")
df_history = pd.DataFrame(epoch_history)
print(df_history.to_string(index=False))
# Out:
# --- Epoch-wise Validation Metrics ---
#  Epoch  Accuracy  Precision   Recall  F1_Weighted  F1_Macro
#      1  0.750325   0.750412 0.750325     0.748873  0.748721
#      2  0.750325   0.750412 0.750325     0.748873  0.748721
#      3  0.750325   0.750412 0.750325     0.748873  0.748721
#      4  0.750325   0.750412 0.750325     0.748873  0.748721
#      5  0.750325   0.750412 0.750325     0.748873  0.748721
#      6  0.750325   0.750412 0.750325     0.748873  0.748721
#      7  0.750325   0.750412 0.750325     0.748873  0.748721
#      8  0.750325   0.750412 0.750325     0.748873  0.748721
#      9  0.750325   0.750412 0.750325     0.748873  0.748721
#     10  0.750325   0.750412 0.750325     0.748873  0.748721

# %%
# --- Step 8: Final Evaluation on Test Set ---
print("\n--- Final Evaluation on Test Data ---")
y_test_pred = best_model.predict(X_test)

accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='weighted', zero_division=0)
recall = recall_score(y_test, y_test_pred, average='weighted', zero_division=0)
f1_weighted = f1_score(y_test, y_test_pred, average='weighted', zero_division=0)
f1_macro = f1_score(y_test, y_test_pred, average='macro', zero_division=0)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision (Weighted): {precision:.4f}")
print(f"Recall (Weighted): {recall:.4f}")
print(f"F1 Score (Weighted): {f1_weighted:.4f}")
print(f"Macro F1 Score: {f1_macro:.4f}")

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_test_pred, target_names=label_encoder.classes_, zero_division=0))
# Out:
# --- Final Evaluation on Test Data ---
# Accuracy: 0.7865
# Precision (Weighted): 0.7843
# Recall (Weighted): 0.7865
# F1 Score (Weighted): 0.7846
# Macro F1 Score: 0.7844
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         high       0.72      0.69      0.71       153
#          low       0.78      0.72      0.75       154
#       medium       0.75      0.73      0.74       153
#    very high       0.83      0.86      0.85       154
#     very low       0.84      0.92      0.88       154
#
#     accuracy                           0.79       768
#    macro avg       0.78      0.79      0.78       768
# weighted avg       0.78      0.79      0.78       768

# %%
# --- Step 9: Predict on Unknown Test Data ---
try:
    unknown_data = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')  # Same features as X
    # Drop the 'Production (M.Ton)' column from the unknown data
    # This makes the columns match the data the model was trained on (X_train)
    unknown_data_processed = unknown_data.drop(columns=['Production (M.Ton)'], errors='ignore') # Use errors='ignore' in case the column is not present

    unknown_preds = best_model.predict(unknown_data_processed)
    decoded_preds = label_encoder.inverse_transform(unknown_preds)

    print("\n--- Predictions on Unknown Test Data ---")
    # It might be useful to print the predictions alongside the original data if possible
    # For this example, we'll just print the predictions
    for i, pred in enumerate(decoded_preds):
        print(f"Sample {i + 1}: {pred}")

except FileNotFoundError:
    print("\nUnknown test data file not found. Skipping predictions.")
except KeyError as e:
    print(f"\nError processing unknown data: {e}. Make sure the test file has the 'Production (M.Ton)' column if needed for dropping.")
# Out:
# --- Predictions on Unknown Test Data ---
# Sample 1: low
# Sample 2: high
# Sample 3: medium
# Sample 4: very low
# Sample 5: very low
# Sample 6: very high
# Sample 7: medium
# Sample 8: low
# Sample 9: high
# Sample 10: very low
# Sample 11: high
# Sample 12: very high
# Sample 13: very high
# Sample 14: high
# Sample 15: medium
# Sample 16: low
# Sample 17: very low
# Sample 18: low
# Sample 19: very high
# Sample 20: low
# Sample 21: very low
# Sample 22: high
# Sample 23: low
# Sample 24: very high
# Sample 25: very high
# Sample 26: very high
# Sample 27: high
# Sample 28: medium
# Sample 29: high
# Sample 30: very low
# Sample 31: very low
# Sample 32: very low
# Sample 33: low
# Sample 34: very low
# Sample 35: low
# Sample 36: high
# Sample 37: high
# Sample 38: medium
# Sample 39: high
# Sample 40: low
# Sample 41: low
# Sample 42: medium
# Sample 43: high
# Sample 44: very high
# Sample 45: very low
# Sample 46: low
# Sample 47: very low
# Sample 48: very high
# Sample 49: very low
# Sample 50: low
# Sample 51: very low
# Sample 52: medium
# Sample 53: medium
# Sample 54: very high
# Sample 55: medium
# Sample 56: high
# Sample 57: high
# Sample 58: very high
# Sample 59: medium
# Sample 60: very low
# Sample 61: medium
# Sample 62: very high
# Sample 63: very high
# Sample 64: medium
# Sample 65: high
# Sample 66: high
# Sample 67: low
# Sample 68: very low
# Sample 69: very high
# Sample 70: very high
# Sample 71: medium
# Sample 72: medium
# Sample 73: very low
# Sample 74: very low
# Sample 75: low
# Sample 76: medium
# Sample 77: low
# Sample 78: very low
# Sample 79: low
# Sample 80: low
# Sample 81: medium
# Sample 82: very high
# Sample 83: very low
# Sample 84: low
# Sample 85: high
# Sample 86: very high
# Sample 87: very high
# Sample 88: low
# Sample 89: medium
# Sample 90: medium
# Sample 91: very high
# Sample 92: very high
# Sample 93: very low
# Sample 94: low
# Sample 95: very low
# Sample 96: very high
# Sample 97: high
# Sample 98: medium
# Sample 99: very low
# Sample 100: medium
# Sample 101: very low
# Sample 102: very low
# Sample 103: very high
# Sample 104: very low
# Sample 105: very low
# Sample 106: low
# Sample 107: medium
# Sample 108: low
# Sample 109: very high
# Sample 110: very high
# Sample 111: medium
# Sample 112: high
# Sample 113: low
# Sample 114: low
# Sample 115: medium
# Sample 116: very low
# Sample 117: high
# Sample 118: very high
# Sample 119: very high
# Sample 120: low
# Sample 121: low
# Sample 122: medium
# Sample 123: very high
# Sample 124: low
# Sample 125: very high
# Sample 126: medium
# Sample 127: very low
# Sample 128: low
# Sample 129: medium
# Sample 130: very high
# Sample 131: very high
# Sample 132: low
# Sample 133: low
# Sample 134: high
# Sample 135: medium
# Sample 136: very high
# Sample 137: low
# Sample 138: very low
# Sample 139: low
# Sample 140: very high
# Sample 141: very high
# Sample 142: very low
# Sample 143: very high
# Sample 144: very low
# Sample 145: very low
# Sample 146: very low
# Sample 147: very low
# Sample 148: very high
# Sample 149: medium
# Sample 150: high
# Sample 151: medium
# Sample 152: very low
# Sample 153: high
# Sample 154: low
# Sample 155: low
# Sample 156: very high
# Sample 157: high
# Sample 158: medium
# Sample 159: medium
# Sample 160: very high
# Sample 161: very low
# Sample 162: very low
# Sample 163: very high
# Sample 164: very low
# Sample 165: very low
# Sample 166: very low
# Sample 167: very low
# Sample 168: high
# Sample 169: medium
# Sample 170: high
# Sample 171: medium
# Sample 172: very low
# Sample 173: low
# Sample 174: high
# Sample 175: very high
# Sample 176: low
# Sample 177: very high
# Sample 178: low
# Sample 179: medium
# Sample 180: very high
# Sample 181: medium
# Sample 182: low
# Sample 183: very low
# Sample 184: very high
# Sample 185: medium
# Sample 186: medium
# Sample 187: very low
# Sample 188: very high
# Sample 189: very high
# Sample 190: very high
# Sample 191: high
# Sample 192: high
# Sample 193: high
# Sample 194: high
# Sample 195: high
# Sample 196: very low
# Sample 197: medium
# Sample 198: medium
# Sample 199: very high
# Sample 200: low
# Sample 201: medium
# Sample 202: low
# Sample 203: very low
# Sample 204: medium
# Sample 205: very low
# Sample 206: low
# Sample 207: low
# Sample 208: low
# Sample 209: very high
# Sample 210: medium
# Sample 211: low
# Sample 212: very low
# Sample 213: very low
# Sample 214: low
# Sample 215: high
# Sample 216: very low
# Sample 217: very high
# Sample 218: low
# Sample 219: medium
# Sample 220: very low
# Sample 221: low
# Sample 222: very high
# Sample 223: high
# Sample 224: low
# Sample 225: low
# Sample 226: very high
# Sample 227: medium
# Sample 228: high
# Sample 229: low
# Sample 230: low
# Sample 231: medium
# Sample 232: very high
# Sample 233: very high
# Sample 234: high
# Sample 235: medium
# Sample 236: very high
# Sample 237: high
# Sample 238: low
# Sample 239: medium
# Sample 240: medium
# Sample 241: very high
# Sample 242: medium
# Sample 243: medium
# Sample 244: medium
# Sample 245: very high
# Sample 246: very high
# Sample 247: medium
# Sample 248: medium
# Sample 249: medium
# Sample 250: high
# Sample 251: high
# Sample 252: very low
# Sample 253: high
# Sample 254: very high
# Sample 255: low
# Sample 256: medium
# Sample 257: high
# Sample 258: very high
# Sample 259: very high
# Sample 260: very low
# Sample 261: very high
# Sample 262: very high
# Sample 263: very low
# Sample 264: very high
# Sample 265: medium
# Sample 266: very low
# Sample 267: very high
# Sample 268: high
# Sample 269: medium
# Sample 270: very high
# Sample 271: low
# Sample 272: very low
# Sample 273: low
# Sample 274: medium
# Sample 275: very low
# Sample 276: very low
# Sample 277: low
# Sample 278: medium
# Sample 279: high
# Sample 280: low
# Sample 281: low
# Sample 282: very low
# Sample 283: high
# Sample 284: low
# Sample 285: medium
# Sample 286: low
# Sample 287: very low
# Sample 288: very high
# Sample 289: high
# Sample 290: medium
# Sample 291: low
# Sample 292: very low
# Sample 293: very low
# Sample 294: very low
# Sample 295: very low
# Sample 296: very low
# Sample 297: low
# Sample 298: very high
# Sample 299: medium
# Sample 300: low
# Sample 301: low
# Sample 302: high
# Sample 303: very high
# Sample 304: very low
# Sample 305: low
# Sample 306: medium
# Sample 307: medium
# Sample 308: very low
# Sample 309: very high
# Sample 310: low
# Sample 311: very low
# Sample 312: high
# Sample 313: very low
# Sample 314: medium
# Sample 315: low
# Sample 316: very high
# Sample 317: medium
# Sample 318: very high
# Sample 319: medium
# Sample 320: low
# Sample 321: very high
# Sample 322: very high
# Sample 323: very low
# Sample 324: high
# Sample 325: very high
# Sample 326: very low
# Sample 327: very high
# Sample 328: low
# Sample 329: very low
# Sample 330: high
# Sample 331: high
# Sample 332: very low
# Sample 333: medium
# Sample 334: very high
# Sample 335: very low
# Sample 336: medium
# Sample 337: very low
# Sample 338: very low
# Sample 339: very high
# Sample 340: very high
# Sample 341: very high
# Sample 342: very high
# Sample 343: low
# Sample 344: very high
# Sample 345: low
# Sample 346: medium
# Sample 347: high
# Sample 348: medium
# Sample 349: low
# Sample 350: medium
# Sample 351: high
# Sample 352: high
# Sample 353: very high
# Sample 354: medium
# Sample 355: very high
# Sample 356: medium
# Sample 357: very high
# Sample 358: very high
# Sample 359: low
# Sample 360: very high
# Sample 361: very high
# Sample 362: very high
# Sample 363: very high
# Sample 364: very high
# Sample 365: very low
# Sample 366: very high
# Sample 367: high
# Sample 368: very high
# Sample 369: low
# Sample 370: medium
# Sample 371: very high
# Sample 372: medium
# Sample 373: high
# Sample 374: high
# Sample 375: medium
# Sample 376: low
# Sample 377: high
# Sample 378: high
# Sample 379: low
# Sample 380: high
# Sample 381: high
# Sample 382: very high
# Sample 383: very low
# Sample 384: high
# Sample 385: very low
# Sample 386: medium
# Sample 387: very high
# Sample 388: medium
# Sample 389: medium
# Sample 390: very high
# Sample 391: low
# Sample 392: very high
# Sample 393: high
# Sample 394: high
# Sample 395: high
# Sample 396: very high
# Sample 397: high
# Sample 398: very high
# Sample 399: low
# Sample 400: low
# Sample 401: low
# Sample 402: very low
# Sample 403: very high
# Sample 404: very low
# Sample 405: low
# Sample 406: low
# Sample 407: very high
# Sample 408: very high
# Sample 409: low
# Sample 410: medium
# Sample 411: very low
# Sample 412: low
# Sample 413: medium
# Sample 414: medium
# Sample 415: very low
# Sample 416: medium
# Sample 417: medium
# Sample 418: very low
# Sample 419: low
# Sample 420: low
# Sample 421: very high
# Sample 422: high
# Sample 423: low
# Sample 424: very low
# Sample 425: high
# Sample 426: medium
# Sample 427: medium
# Sample 428: medium
# Sample 429: very low
# Sample 430: high
# Sample 431: very high
# Sample 432: very high
# Sample 433: medium
# Sample 434: medium
# Sample 435: high
# Sample 436: low
# Sample 437: very high
# Sample 438: low
# Sample 439: very low
# Sample 440: medium
# Sample 441: medium
# Sample 442: high
# Sample 443: very low
# Sample 444: very high
# Sample 445: low
# Sample 446: medium
# Sample 447: very low
# Sample 448: very high
# Sample 449: very low
# Sample 450: very low
# Sample 451: medium
# Sample 452: very low
# Sample 453: very low
# Sample 454: medium
# Sample 455: very low
# Sample 456: medium
# Sample 457: very high
# Sample 458: very high
# Sample 459: high
# Sample 460: low
# Sample 461: high
# Sample 462: low
# Sample 463: very low
# Sample 464: medium
# Sample 465: low
# Sample 466: very low
# Sample 467: low
# Sample 468: very low
# Sample 469: very low
# Sample 470: very low
# Sample 471: very high
# Sample 472: low
# Sample 473: low
# Sample 474: medium
# Sample 475: medium
# Sample 476: very high
# Sample 477: very high
# Sample 478: very low
# Sample 479: very low
# Sample 480: medium
# Sample 481: high
# Sample 482: low
# Sample 483: medium
# Sample 484: very low
# Sample 485: low
# Sample 486: medium
# Sample 487: medium
# Sample 488: high
# Sample 489: very low
# Sample 490: low
# Sample 491: high
# Sample 492: very low
# Sample 493: very low
# Sample 494: very high
# Sample 495: medium
# Sample 496: very high
# Sample 497: low
# Sample 498: medium
# Sample 499: very high
# Sample 500: high
# Sample 501: low
# Sample 502: very high
# Sample 503: low
# Sample 504: medium
# Sample 505: low
# Sample 506: very high
# Sample 507: high
# Sample 508: medium
# Sample 509: low
# Sample 510: medium
# Sample 511: high
# Sample 512: low
# Sample 513: high
# Sample 514: very high
# Sample 515: very high
# Sample 516: high
# Sample 517: high
# Sample 518: high
# Sample 519: very high
# Sample 520: medium
# Sample 521: very high
# Sample 522: high
# Sample 523: high
# Sample 524: low
# Sample 525: medium
# Sample 526: medium
# Sample 527: high
# Sample 528: very high
# Sample 529: high
# Sample 530: very high
# Sample 531: medium
# Sample 532: very high
# Sample 533: medium
# Sample 534: very low
# Sample 535: very low
# Sample 536: high
# Sample 537: medium
# Sample 538: very low
# Sample 539: very high
# Sample 540: medium
# Sample 541: medium
# Sample 542: very high
# Sample 543: low
# Sample 544: very low
# Sample 545: medium
# Sample 546: very low
# Sample 547: very low
# Sample 548: high
# Sample 549: medium
# Sample 550: high
# Sample 551: high
# Sample 552: high
# Sample 553: medium
# Sample 554: very high
# Sample 555: medium
# Sample 556: very high
# Sample 557: very low
# Sample 558: very high
# Sample 559: medium
# Sample 560: very high
# Sample 561: low
# Sample 562: medium
# Sample 563: medium
# Sample 564: very low
# Sample 565: medium
# Sample 566: very high
# Sample 567: high
# Sample 568: very low
# Sample 569: very low
# Sample 570: medium
# Sample 571: very high
# Sample 572: very high
# Sample 573: very high
# Sample 574: very high
# Sample 575: high
# Sample 576: medium
# Sample 577: low
# Sample 578: very low
# Sample 579: very low
# Sample 580: high
# Sample 581: medium
# Sample 582: very low
# Sample 583: very high
# Sample 584: high
# Sample 585: high
# Sample 586: low
# Sample 587: high
# Sample 588: high
# Sample 589: medium
# Sample 590: high
# Sample 591: high
# Sample 592: high
# Sample 593: very low
# Sample 594: medium
# Sample 595: high
# Sample 596: medium
# Sample 597: very low
# Sample 598: high
# Sample 599: low
# Sample 600: low
# Sample 601: very high
# Sample 602: low
# Sample 603: very low
# Sample 604: medium
# Sample 605: very high
# Sample 606: very high
# Sample 607: low
# Sample 608: high
# Sample 609: low
# Sample 610: very high
# Sample 611: very low
# Sample 612: medium
# Sample 613: low
# Sample 614: very low
# Sample 615: very high
# Sample 616: very high
# Sample 617: low
# Sample 618: very low
# Sample 619: high
# Sample 620: medium
# Sample 621: very low
# Sample 622: medium
# Sample 623: very high
# Sample 624: low
# Sample 625: medium
# Sample 626: medium
# Sample 627: very low
# Sample 628: low
# Sample 629: low
# Sample 630: very high
# Sample 631: very low
# Sample 632: low
# Sample 633: high
# Sample 634: medium
# Sample 635: very low
# Sample 636: very high
# Sample 637: high
# Sample 638: very low
# Sample 639: high
# Sample 640: very low
# Sample 641: very high
# Sample 642: high
# Sample 643: high
# Sample 644: very high
# Sample 645: low
# Sample 646: very low
# Sample 647: medium
# Sample 648: very high
# Sample 649: very low
# Sample 650: high
# Sample 651: very high
# Sample 652: low
# Sample 653: medium
# Sample 654: low
# Sample 655: very high
# Sample 656: high
# Sample 657: medium
# Sample 658: very high
# Sample 659: very low
# Sample 660: very low
# Sample 661: very high
# Sample 662: low
# Sample 663: very low
# Sample 664: very high
# Sample 665: high
# Sample 666: high
# Sample 667: high
# Sample 668: medium
# Sample 669: medium
# Sample 670: low
# Sample 671: high
# Sample 672: low
# Sample 673: medium
# Sample 674: medium
# Sample 675: low
# Sample 676: low
# Sample 677: medium
# Sample 678: medium
# Sample 679: very low
# Sample 680: low
# Sample 681: low
# Sample 682: very low
# Sample 683: very high
# Sample 684: low
# Sample 685: low
# Sample 686: low
# Sample 687: very high
# Sample 688: medium
# Sample 689: very low
# Sample 690: medium
# Sample 691: medium
# Sample 692: low
# Sample 693: very high
# Sample 694: low
# Sample 695: high
# Sample 696: very low
# Sample 697: low
# Sample 698: very low
# Sample 699: very high
# Sample 700: medium
# Sample 701: very low
# Sample 702: very low
# Sample 703: medium
# Sample 704: low
# Sample 705: medium
# Sample 706: medium
# Sample 707: very high
# Sample 708: very low
# Sample 709: medium
# Sample 710: very high
# Sample 711: very high
# Sample 712: high
# Sample 713: medium
# Sample 714: very low
# Sample 715: medium
# Sample 716: medium
# Sample 717: very low
# Sample 718: very low
# Sample 719: very high
# Sample 720: low
# Sample 721: very high
# Sample 722: very high
# Sample 723: very low
# Sample 724: high
# Sample 725: very high
# Sample 726: very high
# Sample 727: low
# Sample 728: low
# Sample 729: very low
# Sample 730: very high
# Sample 731: very high
# Sample 732: very low
# Sample 733: low
# Sample 734: high
# Sample 735: very low
# Sample 736: medium
# Sample 737: very high
# Sample 738: very low
# Sample 739: very high
# Sample 740: very low
# Sample 741: high
# Sample 742: low
# Sample 743: very high
# Sample 744: medium
# Sample 745: low
# Sample 746: high
# Sample 747: medium
# Sample 748: high
# Sample 749: very low
# Sample 750: low
# Sample 751: high
# Sample 752: low
# Sample 753: very low
# Sample 754: medium
# Sample 755: very low
# Sample 756: medium
# Sample 757: very high
# Sample 758: high
# Sample 759: medium
# Sample 760: low
# Sample 761: low
# Sample 762: very low
# Sample 763: low
# Sample 764: very high
# Sample 765: very low
# Sample 766: low
# Sample 767: low
# Sample 768: high
