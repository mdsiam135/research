# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/ResNet(3_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, Add, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("Step 1: Libraries imported successfully!")

# Step 2: Load and preprocess data
def load_and_preprocess_data():
    """Load and preprocess the CSV files"""
    print("\nStep 2: Loading data...")

    try:
        # Load CSV files
        train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
        val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
        test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')

        print(f"Train data shape: {train_df.shape}")
        print(f"Validation data shape: {val_df.shape}")
        print(f"Test data shape: {test_df.shape}")

        # Display basic info about the data
        print(f"\nDataset columns: {train_df.columns.tolist()}")
        print(f"Production range in training: {train_df['Production (M.Ton)'].min():.2f} - {train_df['Production (M.Ton)'].max():.2f}")

        return train_df, val_df, test_df

    except FileNotFoundError as e:
        print(f"Error: Could not find one or more CSV files.")
        print(f"Please ensure train.csv, validation.csv, and test.csv are in the current directory.")
        raise e

# Step 3: Create 3-class quantile-based labels
def create_quantile_labels(train_df, val_df, test_df):
    """Create 3-class quantile-based labels for production (Low, Medium, High)"""
    print("\nStep 3: Creating 3-class quantile-based labels...")

    # Calculate quantiles based on training data (33.33% and 66.67% for 3 classes)
    production_col = 'Production (M.Ton)'
    quantiles = train_df[production_col].quantile([0.3333, 0.6667]).values

    print(f"Quantile thresholds:")
    print(f"  Low/Medium boundary: {quantiles[0]:.4f}")
    print(f"  Medium/High boundary: {quantiles[1]:.4f}")

    def assign_labels(production_values, quantiles):
        labels = []
        for val in production_values:
            if val <= quantiles[0]:
                labels.append(0)  # Low
            elif val <= quantiles[1]:
                labels.append(1)  # Medium
            else:
                labels.append(2)  # High
        return np.array(labels)

    # Create labels for all datasets
    y_train = assign_labels(train_df[production_col], quantiles)
    y_val = assign_labels(val_df[production_col], quantiles)
    y_test = assign_labels(test_df[production_col], quantiles)

    # Print label distribution
    label_names = ['Low', 'Medium', 'High']
    print(f"\nLabel distribution:")
    print(f"{'Class':<10} {'Train':<8} {'Val':<8} {'Test':<8}")
    print("-" * 35)
    for i, name in enumerate(label_names):
        train_count = np.sum(y_train == i)
        val_count = np.sum(y_val == i)
        test_count = np.sum(y_test == i)
        print(f"{name:<10} {train_count:<8} {val_count:<8} {test_count:<8}")

    return y_train, y_val, y_test, quantiles

# Step 4: Prepare features
def prepare_features(train_df, val_df, test_df):
    """Prepare feature matrices"""
    print("\nStep 4: Preparing features...")

    # Drop the target column
    feature_cols = [col for col in train_df.columns if col != 'Production (M.Ton)']

    X_train = train_df[feature_cols].values
    X_val = val_df[feature_cols].values
    X_test = test_df[feature_cols].values

    print(f"Number of features: {len(feature_cols)}")

    # Handle missing values
    X_train = np.nan_to_num(X_train)
    X_val = np.nan_to_num(X_val)
    X_test = np.nan_to_num(X_test)

    # Standardize features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    print(f"Feature matrix shapes:")
    print(f"  X_train: {X_train_scaled.shape}")
    print(f"  X_val: {X_val_scaled.shape}")
    print(f"  X_test: {X_test_scaled.shape}")

    return X_train_scaled, X_val_scaled, X_test_scaled, scaler, feature_cols

# Step 5: Build ResNet model
def residual_block(x, units, dropout_rate=0.2):
    """Create a residual block"""
    # Save input for skip connection
    shortcut = x

    # First layer
    x = Dense(units)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)

    # Second layer
    x = Dense(units)(x)
    x = BatchNormalization()(x)

    # Adjust shortcut dimensions if needed
    if shortcut.shape[-1] != units:
        shortcut = Dense(units)(shortcut)
        shortcut = BatchNormalization()(shortcut)

    # Add skip connection
    x = Add()([x, shortcut])
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)

    return x

def build_resnet_model(input_dim, num_classes=3):
    """Build ResNet model for 3-class classification"""
    print(f"\nStep 5: Building ResNet model for {num_classes}-class classification...")

    # Input layer
    inputs = Input(shape=(input_dim,))

    # Initial dense layer
    x = Dense(256)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.3)(x)

    # Residual blocks with different sizes
    x = residual_block(x, 512, 0.3)
    x = residual_block(x, 512, 0.3)
    x = residual_block(x, 256, 0.25)
    x = residual_block(x, 256, 0.25)
    x = residual_block(x, 128, 0.2)
    x = residual_block(x, 128, 0.2)

    # Final dense layers
    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.2)(x)

    x = Dense(32)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.1)(x)

    # Output layer
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create model
    model = Model(inputs=inputs, outputs=outputs)

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("Model architecture:")
    model.summary()

    return model

# Step 6: Train the model
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the ResNet model"""
    print(f"\nStep 6: Training model for {epochs} epochs...")

    # Convert labels to categorical
    y_train_cat = to_categorical(y_train, 3)
    y_val_cat = to_categorical(y_val, 3)

    print(f"Training labels shape: {y_train_cat.shape}")
    print(f"Validation labels shape: {y_val_cat.shape}")

    # Callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    )

    # Train model
    history = model.fit(
        X_train, y_train_cat,
        validation_data=(X_val, y_val_cat),
        epochs=epochs,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    print(f"Training completed! Total epochs: {len(history.history['loss'])}")

    return history

# Step 7: Evaluation functions
def calculate_metrics(y_true, y_pred):
    """Calculate classification metrics"""
    accuracy = accuracy_score(y_true, y_pred)
    precision_weighted = precision_score(y_true, y_pred, average='weighted')
    precision_macro = precision_score(y_true, y_pred, average='macro')
    recall_weighted = recall_score(y_true, y_pred, average='weighted')
    recall_macro = recall_score(y_true, y_pred, average='macro')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')
    f1_macro = f1_score(y_true, y_pred, average='macro')

    return {
        'Accuracy': accuracy,
        'Precision (Weighted)': precision_weighted,
        'Precision (Macro)': precision_macro,
        'Recall (Weighted)': recall_weighted,
        'Recall (Macro)': recall_macro,
        'F1 Score (Weighted)': f1_weighted,
        'F1 Score (Macro)': f1_macro
    }

def plot_confusion_matrix(y_true, y_pred, title, dataset_name):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)
    labels = ['Low', 'Medium', 'High']

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels,
                cbar_kws={'label': 'Count'})
    plt.title(f'{title} - {dataset_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()

    return cm

def plot_training_history(history):
    """Plot training and validation accuracy/loss"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot accuracy
    epochs = range(1, len(history.history['accuracy']) + 1)
    ax1.plot(epochs, history.history['accuracy'], 'b-o', label='Training Accuracy', linewidth=2, markersize=4)
    ax1.plot(epochs, history.history['val_accuracy'], 'r-s', label='Validation Accuracy', linewidth=2, markersize=4)
    ax1.set_title('Model Accuracy Over Epochs', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True, alpha=0.3)
    ax1.set_ylim([0, 1])

    # Plot loss
    ax2.plot(epochs, history.history['loss'], 'b-o', label='Training Loss', linewidth=2, markersize=4)
    ax2.plot(epochs, history.history['val_loss'], 'r-s', label='Validation Loss', linewidth=2, markersize=4)
    ax2.set_title('Model Loss Over Epochs', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

    # Print final metrics
    final_train_acc = history.history['accuracy'][-1]
    final_val_acc = history.history['val_accuracy'][-1]
    final_train_loss = history.history['loss'][-1]
    final_val_loss = history.history['val_loss'][-1]

    print(f"\nFinal Training Metrics:")
    print(f"  Training Accuracy: {final_train_acc:.4f}")
    print(f"  Training Loss: {final_train_loss:.4f}")
    print(f"  Validation Accuracy: {final_val_acc:.4f}")
    print(f"  Validation Loss: {final_val_loss:.4f}")

# Step 8: Detailed evaluation and reporting
def evaluate_model(model, X_val, y_val, X_test, y_test, dataset_names=['Validation', 'Test']):
    """Evaluate model on validation and test sets"""
    print("\nStep 8: Evaluating model...")

    # Make predictions
    y_val_pred = np.argmax(model.predict(X_val, verbose=0), axis=1)
    y_test_pred = np.argmax(model.predict(X_test, verbose=0), axis=1)

    datasets = [(y_val, y_val_pred, 'Validation'), (y_test, y_test_pred, 'Test')]
    results = {}

    for y_true, y_pred, name in datasets:
        print(f"\n{'='*60}")
        print(f"{name.upper()} SET RESULTS")
        print('='*60)

        # Calculate metrics
        metrics = calculate_metrics(y_true, y_pred)
        results[name] = metrics

        # Display metrics
        for metric, value in metrics.items():
            print(f"{metric:<25}: {value:.4f}")

        # Plot confusion matrix
        cm = plot_confusion_matrix(y_true, y_pred, "Confusion Matrix", f"{name} Set")

        # Print detailed classification report
        print(f"\nDetailed Classification Report - {name} Set:")
        print("-" * 50)
        labels = ['Low', 'Medium', 'High']
        print(classification_report(y_true, y_pred, target_names=labels, digits=4))

    return results, y_val_pred, y_test_pred

# Step 9: Main execution function
def main(epochs=100):
    """Main execution function"""
    print("Starting ResNet Crop Production Classification Pipeline (3 Classes)")
    print("="*70)

    try:
        # Load data
        train_df, val_df, test_df = load_and_preprocess_data()

        # Create 3-class labels
        y_train, y_val, y_test, quantiles = create_quantile_labels(train_df, val_df, test_df)

        # Prepare features
        X_train, X_val, X_test, scaler, feature_cols = prepare_features(train_df, val_df, test_df)

        # Build model
        model = build_resnet_model(X_train.shape[1], num_classes=3)

        # Train model
        history = train_model(model, X_train, y_train, X_val, y_val, epochs=epochs)

        # Plot training history
        plot_training_history(history)

        # Evaluate model
        results, y_val_pred, y_test_pred = evaluate_model(model, X_val, y_val, X_test, y_test)

        # Final summary
        print("\n" + "="*70)
        print("FINAL SUMMARY")
        print("="*70)
        print(f"Model Architecture: ResNet with {len(feature_cols)} input features")
        print(f"Classes: 3 (Low, Medium, High)")
        print(f"Training completed in {len(history.history['loss'])} epochs")
        print(f"\nKey Performance Metrics:")
        print(f"{'Dataset':<12} {'Accuracy':<10} {'Macro F1':<10} {'Weighted F1':<12}")
        print("-" * 45)
        for dataset, metrics in results.items():
            acc = metrics['Accuracy']
            macro_f1 = metrics['F1 Score (Macro)']
            weighted_f1 = metrics['F1 Score (Weighted)']
            print(f"{dataset:<12} {acc:<10.4f} {macro_f1:<10.4f} {weighted_f1:<12.4f}")

        print(f"\nQuantile Boundaries:")
        print(f"  Low ≤ {quantiles[0]:.4f} < Medium ≤ {quantiles[1]:.4f} < High")

        return {
            'model': model,
            'history': history,
            'results': results,
            'scaler': scaler,
            'quantiles': quantiles,
            'feature_cols': feature_cols
        }

    except Exception as e:
        print(f"An error occurred: {e}")
        import traceback
        traceback.print_exc()
        return None

# Step 10: Run the complete pipeline
if __name__ == "__main__":
    # You can modify the number of epochs here
    EPOCHS = 100

    print(f"Configuration: {EPOCHS} epochs, 3-class classification")
    print("Required files: train.csv, validation.csv, test.csv")
    print()

    # Execute main function
    pipeline_results = main(epochs=EPOCHS)

    if pipeline_results:
        print("\n🎉 Pipeline completed successfully!")
        print("\nWhat was accomplished:")
        print("✅ Loaded and preprocessed 3 CSV files")
        print("✅ Created 3-class quantile-based labels (Low, Medium, High)")
        print("✅ Built and trained ResNet model")
        print("✅ Generated all requested metrics (Accuracy, Precision, Recall, F1, Macro F1)")
        print("✅ Plotted confusion matrices for validation and test sets")
        print("✅ Plotted training vs validation accuracy curves")
        print("✅ Provided detailed classification reports")

        # Optionally save the model
        save_model = input("\nDo you want to save the trained model? (y/n): ").lower().strip()
        if save_model == 'y':
            pipeline_results['model'].save('resnet_crop_production_3class.h5')
            print("Model saved as 'resnet_crop_production_3class.h5'")
    else:
        print("\n❌ Pipeline failed. Please check your data files and try again.")
        print("Make sure train.csv, validation.csv, and test.csv are in the current directory.")
# Out:
# Step 1: Libraries imported successfully!
# Configuration: 100 epochs, 3-class classification
# Required files: train.csv, validation.csv, test.csv
#
# Starting ResNet Crop Production Classification Pipeline (3 Classes)
# ======================================================================
#
# Step 2: Loading data...
# Train data shape: (3584, 84)
# Validation data shape: (768, 84)
# Test data shape: (768, 84)
#
# Dataset columns: ['Production (M.Ton)', 'Area (Acres)', 'Temperature at 2 Meters Range (C) ', 'Year', 'soil_temperature_0_to_7cm(C)', 'soil_moisture_0_to_7cm(mÂ³/mÂ³)', 'soil_moiture_7_to_28cm(mÂ³/mÂ³)', 'Root Zone Soil Wetness (surface to 100 cm below)', 'total_rain_mm', 'Surface Soil Wetness  (surface to 5 cm below)', 'relative_humidity_2m(%)', 'Precipitation Corrected (mm) ', 'Crop_Beans', 'Crop_Cabbage', 'Crop_Cauliflower', 'Crop_Garlic', 'Crop_Laushak', 'Crop_Onion', 'Crop_Radish', 'Crop_Tomato', 'District_Bagerhat', 'District_Bandarban', 'District_Barguna', 'District_Barishal', 'District_Bhola', 'District_Bogura', 'District_Brahmanbaria', 'District_Chandpur', 'District_Chapai Nawabganj', 'District_Chattogram', 'District_Chuadanga', 'District_Comilla', "District_Cox's Bazar", 'District_Dhaka', 'District_Dinajpur', 'District_Faridpur', 'District_Feni', 'District_Gaibandha', 'District_Gazipur', 'District_Gopalganj', 'District_Habiganj', 'District_Jamalpur', 'District_Jashore', 'District_Jhaliokati', 'District_Jhenaidah', 'District_Joypurhat', 'District_Khagrachari', 'District_Khulna', 'District_Kishoreganj', 'District_Kurigram', 'District_Kushtia', 'District_Lakshmipur', 'District_Lalmonirhat', 'District_Madaripur', 'District_Magura', 'District_Manikganj', 'District_Maulvibazar', 'District_Meherpur', 'District_Munshiganj', 'District_Mymensingh', 'District_Naogaon', 'District_Narail', 'District_Narayanganj', 'District_Narsingdi', 'District_Natore', 'District_Netrakona', 'District_Nilphamari', 'District_Noakhali', 'District_Pabna', 'District_Panchagarh', 'District_Patuakhali', 'District_Pirojpur', 'District_Rajbari', 'District_Rajshahi', 'District_Rangamati', 'District_Rangpur', 'District_Satkhira', 'District_Shariatpur', 'District_Sherpur', 'District_Sirajganj', 'District_Sunamganj', 'District_Sylhet', 'District_Tangail', 'District_Thakurgaon']
# Production range in training: 0.00 - 544979.54
#
# Step 3: Creating 3-class quantile-based labels...
# Quantile thresholds:
#   Low/Medium boundary: 1061.0000
#   Medium/High boundary: 3923.9305
#
# Label distribution:
# Class      Train    Val      Test
# -----------------------------------
# Low        1196     251      255
# Medium     1193     260      264
# High       1195     257      249
#
# Step 4: Preparing features...
# Number of features: 83
# Feature matrix shapes:
#   X_train: (3584, 83)
#   X_val: (768, 83)
#   X_test: (768, 83)
#
# Step 5: Building ResNet model for 3-class classification...
# Model architecture:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 83)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_38 (Dense)    │ (None, 256)       │     21,504 │ input_layer_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_38[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_30 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 256)       │          0 │ re_lu_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_39 (Dense)    │ (None, 512)       │    131,584 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_39[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_31 (ReLU)     │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 512)       │          0 │ re_lu_31[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_40 (Dense)    │ (None, 512)       │    262,656 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_41 (Dense)    │ (None, 512)       │    131,584 │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_40[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_41[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_12 (Add)        │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_32 (ReLU)     │ (None, 512)       │          0 │ add_12[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 512)       │          0 │ re_lu_32[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_42 (Dense)    │ (None, 512)       │    262,656 │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_42[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_33 (ReLU)     │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_33          │ (None, 512)       │          0 │ re_lu_33[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_43 (Dense)    │ (None, 512)       │    262,656 │ dropout_33[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_43[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_13 (Add)        │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_34 (ReLU)     │ (None, 512)       │          0 │ add_13[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 512)       │          0 │ re_lu_34[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_44 (Dense)    │ (None, 256)       │    131,328 │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_44[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_35 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 256)       │          0 │ re_lu_35[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_45 (Dense)    │ (None, 256)       │     65,792 │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_46 (Dense)    │ (None, 256)       │    131,328 │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_45[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_46[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_14 (Add)        │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_36 (ReLU)     │ (None, 256)       │          0 │ add_14[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 256)       │          0 │ re_lu_36[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_47 (Dense)    │ (None, 256)       │     65,792 │ dropout_36[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_47[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_37 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_37          │ (None, 256)       │          0 │ re_lu_37[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_48 (Dense)    │ (None, 256)       │     65,792 │ dropout_37[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_48[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_15 (Add)        │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_36[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_38 (ReLU)     │ (None, 256)       │          0 │ add_15[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 256)       │          0 │ re_lu_38[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_49 (Dense)    │ (None, 128)       │     32,896 │ dropout_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_49[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_39 (ReLU)     │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 128)       │          0 │ re_lu_39[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_50 (Dense)    │ (None, 128)       │     16,512 │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_51 (Dense)    │ (None, 128)       │     32,896 │ dropout_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_50[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_51[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_16 (Add)        │ (None, 128)       │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_40 (ReLU)     │ (None, 128)       │          0 │ add_16[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 128)       │          0 │ re_lu_40[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_52 (Dense)    │ (None, 128)       │     16,512 │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_52[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_41 (ReLU)     │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_41          │ (None, 128)       │          0 │ re_lu_41[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_53 (Dense)    │ (None, 128)       │     16,512 │ dropout_41[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_53[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_17 (Add)        │ (None, 128)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_40[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_42 (ReLU)     │ (None, 128)       │          0 │ add_17[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_42          │ (None, 128)       │          0 │ re_lu_42[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_54 (Dense)    │ (None, 64)        │      8,256 │ dropout_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64)        │        256 │ dense_54[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_43 (ReLU)     │ (None, 64)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_43          │ (None, 64)        │          0 │ re_lu_43[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_55 (Dense)    │ (None, 32)        │      2,080 │ dropout_43[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32)        │        128 │ dense_55[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_44 (ReLU)     │ (None, 32)        │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_44          │ (None, 32)        │          0 │ re_lu_44[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_56 (Dense)    │ (None, 3)         │         99 │ dropout_44[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,677,763 (6.40 MB)
#  Trainable params: 1,668,099 (6.36 MB)
#  Non-trainable params: 9,664 (37.75 KB)
# Step 6: Training model for 100 epochs...
# Training labels shape: (3584, 3)
# Validation labels shape: (768, 3)
# Epoch 1/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 26s 69ms/step - accuracy: 0.3212 - loss: 1.3237 - val_accuracy: 0.3763 - val_loss: 1.0909 - learning_rate: 0.0010
# Epoch 2/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.3374 - loss: 1.1612 - val_accuracy: 0.4661 - val_loss: 1.0442 - learning_rate: 0.0010
# Epoch 3/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.4032 - loss: 1.1056 - val_accuracy: 0.5417 - val_loss: 0.9113 - learning_rate: 0.0010
# Epoch 4/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.5187 - loss: 0.9795 - val_accuracy: 0.6393 - val_loss: 0.7582 - learning_rate: 0.0010
# Epoch 5/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.6147 - loss: 0.8397 - val_accuracy: 0.6693 - val_loss: 0.7318 - learning_rate: 0.0010
# Epoch 6/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.6560 - loss: 0.7553 - val_accuracy: 0.6784 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 7/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.6860 - loss: 0.7135 - val_accuracy: 0.7474 - val_loss: 0.5907 - learning_rate: 0.0010
# Epoch 8/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - accuracy: 0.7234 - loss: 0.6345 - val_accuracy: 0.7747 - val_loss: 0.5433 - learning_rate: 0.0010
# Epoch 9/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - accuracy: 0.7343 - loss: 0.6170 - val_accuracy: 0.8060 - val_loss: 0.4870 - learning_rate: 0.0010
# Epoch 10/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 10s 53ms/step - accuracy: 0.7720 - loss: 0.5452 - val_accuracy: 0.8281 - val_loss: 0.4479 - learning_rate: 0.0010
# Epoch 11/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.7934 - loss: 0.5051 - val_accuracy: 0.8307 - val_loss: 0.4086 - learning_rate: 0.0010
# Epoch 12/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.7914 - loss: 0.5061 - val_accuracy: 0.8385 - val_loss: 0.4105 - learning_rate: 0.0010
# Epoch 13/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8255 - loss: 0.4419 - val_accuracy: 0.8750 - val_loss: 0.3457 - learning_rate: 0.0010
# Epoch 14/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8186 - loss: 0.4346 - val_accuracy: 0.8737 - val_loss: 0.3336 - learning_rate: 0.0010
# Epoch 15/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.8346 - loss: 0.4233 - val_accuracy: 0.8698 - val_loss: 0.3520 - learning_rate: 0.0010
# Epoch 16/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - accuracy: 0.8368 - loss: 0.3968 - val_accuracy: 0.8737 - val_loss: 0.3276 - learning_rate: 0.0010
# Epoch 17/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.8512 - loss: 0.3902 - val_accuracy: 0.8789 - val_loss: 0.3286 - learning_rate: 0.0010
# Epoch 18/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8615 - loss: 0.3744 - val_accuracy: 0.8789 - val_loss: 0.3092 - learning_rate: 0.0010
# Epoch 19/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8727 - loss: 0.3480 - val_accuracy: 0.8854 - val_loss: 0.3053 - learning_rate: 0.0010
# Epoch 20/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.8631 - loss: 0.3401 - val_accuracy: 0.8672 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 21/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.8812 - loss: 0.3380 - val_accuracy: 0.8958 - val_loss: 0.2908 - learning_rate: 0.0010
# Epoch 22/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8793 - loss: 0.3336 - val_accuracy: 0.8880 - val_loss: 0.2798 - learning_rate: 0.0010
# Epoch 23/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 44ms/step - accuracy: 0.8874 - loss: 0.3039 - val_accuracy: 0.8893 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 24/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.8922 - loss: 0.3046 - val_accuracy: 0.8932 - val_loss: 0.2734 - learning_rate: 0.0010
# Epoch 25/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.8950 - loss: 0.2960 - val_accuracy: 0.8945 - val_loss: 0.2763 - learning_rate: 0.0010
# Epoch 26/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.8978 - loss: 0.2808 - val_accuracy: 0.8945 - val_loss: 0.2740 - learning_rate: 0.0010
# Epoch 27/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9004 - loss: 0.2804 - val_accuracy: 0.9010 - val_loss: 0.3014 - learning_rate: 0.0010
# Epoch 28/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - accuracy: 0.9065 - loss: 0.2654 - val_accuracy: 0.8958 - val_loss: 0.2666 - learning_rate: 0.0010
# Epoch 29/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9056 - loss: 0.2662 - val_accuracy: 0.9049 - val_loss: 0.2545 - learning_rate: 0.0010
# Epoch 30/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.9036 - loss: 0.2651 - val_accuracy: 0.8945 - val_loss: 0.2914 - learning_rate: 0.0010
# Epoch 31/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9130 - loss: 0.2412 - val_accuracy: 0.8958 - val_loss: 0.2727 - learning_rate: 0.0010
# Epoch 32/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9125 - loss: 0.2355 - val_accuracy: 0.8997 - val_loss: 0.2630 - learning_rate: 0.0010
# Epoch 33/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 11s 53ms/step - accuracy: 0.9267 - loss: 0.2184 - val_accuracy: 0.9102 - val_loss: 0.2742 - learning_rate: 0.0010
# Epoch 34/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.9209 - loss: 0.2217 - val_accuracy: 0.9023 - val_loss: 0.2585 - learning_rate: 0.0010
# Epoch 35/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9216 - loss: 0.2145 - val_accuracy: 0.8984 - val_loss: 0.2759 - learning_rate: 0.0010
# Epoch 36/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - accuracy: 0.9180 - loss: 0.2193 - val_accuracy: 0.9049 - val_loss: 0.2422 - learning_rate: 0.0010
# Epoch 37/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9259 - loss: 0.2013 - val_accuracy: 0.9023 - val_loss: 0.2725 - learning_rate: 0.0010
# Epoch 38/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.9327 - loss: 0.1976 - val_accuracy: 0.9076 - val_loss: 0.2866 - learning_rate: 0.0010
# Epoch 39/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9389 - loss: 0.1865 - val_accuracy: 0.8932 - val_loss: 0.3076 - learning_rate: 0.0010
# Epoch 40/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - accuracy: 0.9276 - loss: 0.2190 - val_accuracy: 0.9010 - val_loss: 0.2819 - learning_rate: 0.0010
# Epoch 41/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9327 - loss: 0.1980 - val_accuracy: 0.8971 - val_loss: 0.3042 - learning_rate: 0.0010
# Epoch 42/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.9351 - loss: 0.1805 - val_accuracy: 0.8997 - val_loss: 0.2912 - learning_rate: 0.0010
# Epoch 43/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9303 - loss: 0.1979 - val_accuracy: 0.8997 - val_loss: 0.2758 - learning_rate: 0.0010
# Epoch 44/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9382 - loss: 0.1827
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.9382 - loss: 0.1827 - val_accuracy: 0.9023 - val_loss: 0.2846 - learning_rate: 0.0010
# Epoch 45/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.9593 - loss: 0.1321 - val_accuracy: 0.9089 - val_loss: 0.2640 - learning_rate: 5.0000e-04
# Epoch 46/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - accuracy: 0.9599 - loss: 0.1258 - val_accuracy: 0.9115 - val_loss: 0.2678 - learning_rate: 5.0000e-04
# Epoch 47/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9590 - loss: 0.1296 - val_accuracy: 0.9128 - val_loss: 0.2702 - learning_rate: 5.0000e-04
# Epoch 48/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - accuracy: 0.9552 - loss: 0.1254 - val_accuracy: 0.9089 - val_loss: 0.2865 - learning_rate: 5.0000e-04
# Epoch 49/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9546 - loss: 0.1201 - val_accuracy: 0.9167 - val_loss: 0.2729 - learning_rate: 5.0000e-04
# Epoch 50/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - accuracy: 0.9600 - loss: 0.1210 - val_accuracy: 0.9128 - val_loss: 0.2871 - learning_rate: 5.0000e-04
# Epoch 51/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9626 - loss: 0.1156 - val_accuracy: 0.9023 - val_loss: 0.2856 - learning_rate: 5.0000e-04
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 36.
# Training completed! Total epochs: 51
# Final Training Metrics:
#   Training Accuracy: 0.9595
#   Training Loss: 0.1206
#   Validation Accuracy: 0.9023
#   Validation Loss: 0.2856
#
# Step 8: Evaluating model...
#
# ============================================================
# VALIDATION SET RESULTS
# ============================================================
# Accuracy                 : 0.9049
# Precision (Weighted)     : 0.9054
# Precision (Macro)        : 0.9060
# Recall (Weighted)        : 0.9049
# Recall (Macro)           : 0.9054
# F1 Score (Weighted)      : 0.9051
# F1 Score (Macro)         : 0.9056
# Detailed Classification Report - Validation Set:
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#          Low     0.9634    0.9442    0.9537       251
#       Medium     0.8643    0.8577    0.8610       260
#         High     0.8902    0.9144    0.9021       257
#
#     accuracy                         0.9049       768
#    macro avg     0.9060    0.9054    0.9056       768
# weighted avg     0.9054    0.9049    0.9051       768
#
#
# ============================================================
# TEST SET RESULTS
# ============================================================
# Accuracy                 : 0.9115
# Precision (Weighted)     : 0.9125
# Precision (Macro)        : 0.9131
# Recall (Weighted)        : 0.9115
# Recall (Macro)           : 0.9116
# F1 Score (Weighted)      : 0.9118
# F1 Score (Macro)         : 0.9122
# Detailed Classification Report - Test Set:
# --------------------------------------------------
#               precision    recall  f1-score   support
#
#          Low     0.9639    0.9412    0.9524       255
#       Medium     0.8608    0.8902    0.8752       264
#         High     0.9146    0.9036    0.9091       249
#
#     accuracy                         0.9115       768
#    macro avg     0.9131    0.9116    0.9122       768
# weighted avg     0.9125    0.9115    0.9118       768
#
#
# ======================================================================
# FINAL SUMMARY
# ======================================================================
# Model Architecture: ResNet with 83 input features
# Classes: 3 (Low, Medium, High)
# Training completed in 51 epochs
#
# Key Performance Metrics:
# Dataset      Accuracy   Macro F1   Weighted F1
# ---------------------------------------------
# Validation   0.9049     0.9056     0.9051
# Test         0.9115     0.9122     0.9118
#
# Quantile Boundaries:
#   Low ≤ 1061.0000 < Medium ≤ 3923.9305 < High
#
# 🎉 Pipeline completed successfully!
#
# What was accomplished:
# ✅ Loaded and preprocessed 3 CSV files
# ✅ Created 3-class quantile-based labels (Low, Medium, High)
# ✅ Built and trained ResNet model
# ✅ Generated all requested metrics (Accuracy, Precision, Recall, F1, Macro F1)
# ✅ Plotted confusion matrices for validation and test sets
# ✅ Plotted training vs validation accuracy curves
# ✅ Provided detailed classification reports
#
# Do you want to save the trained model? (y/n): y
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'resnet_crop_production_3class.h5'
