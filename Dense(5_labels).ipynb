# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/Dense(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

class DenseNetTabular:
    def __init__(self, input_dim, num_classes=5):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.model = None
        self.scaler = StandardScaler()
        self.label_encoder = LabelEncoder()
        self.history = None

    def create_dense_block(self, x, growth_rate, num_layers, name):
        """Create a dense block with specified growth rate and number of layers"""
        for i in range(num_layers):
            # Batch normalization and ReLU activation
            bn = layers.BatchNormalization(name=f'{name}_bn_{i}')(x)
            relu = layers.ReLU(name=f'{name}_relu_{i}')(bn)

            # Dense layer with growth rate
            conv = layers.Dense(growth_rate, name=f'{name}_dense_{i}')(relu)

            # Concatenate with input (skip connection)
            x = layers.Concatenate(name=f'{name}_concat_{i}')([x, conv])

        return x

    def create_transition_layer(self, x, compression_factor, name):
        """Create transition layer for dimensionality reduction"""
        # Get number of features
        num_features = x.shape[-1]

        # Batch normalization and ReLU
        bn = layers.BatchNormalization(name=f'{name}_bn')(x)
        relu = layers.ReLU(name=f'{name}_relu')(bn)

        # Compress features
        compressed_features = int(num_features * compression_factor)
        dense = layers.Dense(compressed_features, name=f'{name}_dense')(relu)

        # Dropout for regularization
        dropout = layers.Dropout(0.2, name=f'{name}_dropout')(dense)

        return dropout

    def build_model(self):
        """Build DenseNet architecture for tabular data"""
        # Input layer
        inputs = layers.Input(shape=(self.input_dim,), name='input')

        # Initial dense layer
        x = layers.Dense(64, activation='relu', name='initial_dense')(inputs)
        x = layers.BatchNormalization(name='initial_bn')(x)
        x = layers.Dropout(0.1, name='initial_dropout')(x)

        # Dense Block 1
        x = self.create_dense_block(x, growth_rate=32, num_layers=4, name='dense_block_1')
        x = self.create_transition_layer(x, compression_factor=0.5, name='transition_1')

        # Dense Block 2
        x = self.create_dense_block(x, growth_rate=32, num_layers=4, name='dense_block_2')
        x = self.create_transition_layer(x, compression_factor=0.5, name='transition_2')

        # Dense Block 3
        x = self.create_dense_block(x, growth_rate=32, num_layers=4, name='dense_block_3')

        # Global Average Pooling equivalent for tabular data
        x = layers.BatchNormalization(name='final_bn')(x)
        x = layers.ReLU(name='final_relu')(x)

        # Classification head
        x = layers.Dense(128, activation='relu', name='classifier_dense_1')(x)
        x = layers.Dropout(0.3, name='classifier_dropout_1')(x)
        x = layers.Dense(64, activation='relu', name='classifier_dense_2')(x)
        x = layers.Dropout(0.2, name='classifier_dropout_2')(x)

        # Output layer
        outputs = layers.Dense(self.num_classes, activation='softmax', name='output')(x)

        # Create model
        self.model = keras.Model(inputs=inputs, outputs=outputs, name='DenseNet_Tabular')

        return self.model

    def compile_model(self, learning_rate=0.001):
        """Compile the model with optimizer and loss function"""
        optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        self.model.compile(
            optimizer=optimizer,
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

    def preprocess_data(self, df, target_column, is_training=True):
        """Preprocess the data for training"""
        # Separate features and target
        X = df.drop(columns=[target_column])
        y = df[target_column]

        if is_training:
            # Create quantile-based labels for training data
            quantiles = y.quantile([0.2, 0.4, 0.6, 0.8])
            labels = []
            for value in y:
                if value <= quantiles[0.2]:
                    labels.append('very_low')
                elif value <= quantiles[0.4]:
                    labels.append('low')
                elif value <= quantiles[0.6]:
                    labels.append('medium')
                elif value <= quantiles[0.8]:
                    labels.append('high')
                else:
                    labels.append('very_high')

            # Store quantiles for later use
            self.quantiles = quantiles

            # Fit label encoder and scaler
            y_encoded = self.label_encoder.fit_transform(labels)
            X_scaled = self.scaler.fit_transform(X)
        else:
            # Use existing quantiles for validation/test data
            labels = []
            for value in y:
                if value <= self.quantiles[0.2]:
                    labels.append('very_low')
                elif value <= self.quantiles[0.4]:
                    labels.append('low')
                elif value <= self.quantiles[0.6]:
                    labels.append('medium')
                elif value <= self.quantiles[0.8]:
                    labels.append('high')
                else:
                    labels.append('very_high')

            # Transform using fitted encoders
            y_encoded = self.label_encoder.transform(labels)
            X_scaled = self.scaler.transform(X)

        # Convert to categorical
        y_categorical = keras.utils.to_categorical(y_encoded, num_classes=self.num_classes)

        return X_scaled, y_categorical, y_encoded, labels

def load_and_preprocess_data():
    """Load and preprocess all datasets"""
    print("Loading datasets...")

    # Load datasets
    train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
    val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')

    print(f"Train dataset shape: {train_df.shape}")
    print(f"Validation dataset shape: {val_df.shape}")
    print(f"Test dataset shape: {test_df.shape}")

    # Check for missing values
    print("\nMissing values in train dataset:")
    print(train_df.isnull().sum().sum())

    # Handle missing values if any
    train_df = train_df.fillna(train_df.mean(numeric_only=True))
    val_df = val_df.fillna(val_df.mean(numeric_only=True))
    test_df = test_df.fillna(test_df.mean(numeric_only=True))

    return train_df, val_df, test_df

def calculate_metrics(y_true, y_pred):
    """Calculate all required metrics"""
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    macro_f1 = f1_score(y_true, y_pred, average='macro')

    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'macro_f1': macro_f1
    }

def plot_confusion_matrix(y_true, y_pred, labels, title, save_path=None):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(title)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)
    plt.show()

def plot_training_history(history, save_path=None):
    """Plot training and validation accuracy/loss"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss')
    ax2.plot(history.history['val_loss'], label='Validation Loss')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path)
    plt.show()

def main():
    """Main function to run the entire pipeline"""

    # Step 1: Load and preprocess data
    print("="*50)
    print("STEP 1: Loading and Preprocessing Data")
    print("="*50)

    train_df, val_df, test_df = load_and_preprocess_data()

    # Step 2: Initialize model
    print("\n" + "="*50)
    print("STEP 2: Initializing DenseNet Model")
    print("="*50)

    # Get input dimension (excluding target column)
    input_dim = train_df.shape[1] - 1  # Subtract 1 for target column

    # Initialize DenseNet
    densenet = DenseNetTabular(input_dim=input_dim, num_classes=5)

    # Step 3: Preprocess datasets
    print("\n" + "="*50)
    print("STEP 3: Preprocessing Datasets")
    print("="*50)

    # Preprocess training data
    X_train, y_train_cat, y_train_encoded, train_labels = densenet.preprocess_data(
        train_df, 'Production (M.Ton)', is_training=True
    )

    # Preprocess validation data
    X_val, y_val_cat, y_val_encoded, val_labels = densenet.preprocess_data(
        val_df, 'Production (M.Ton)', is_training=False
    )

    # Preprocess test data
    X_test, y_test_cat, y_test_encoded, test_labels = densenet.preprocess_data(
        test_df, 'Production (M.Ton)', is_training=False
    )

    print(f"Training data shape: {X_train.shape}")
    print(f"Validation data shape: {X_val.shape}")
    print(f"Test data shape: {X_test.shape}")

    # Step 4: Build and compile model
    print("\n" + "="*50)
    print("STEP 4: Building and Compiling Model")
    print("="*50)

    model = densenet.build_model()
    densenet.compile_model(learning_rate=0.001)

    print("Model Architecture:")
    model.summary()

    # Step 5: Train the model
    print("\n" + "="*50)
    print("STEP 5: Training the Model")
    print("="*50)

    # Define callbacks
    early_stopping = keras.callbacks.EarlyStopping(
        monitor='val_accuracy',
        patience=10,
        restore_best_weights=True
    )

    reduce_lr = keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-7
    )

    # Train the model
    epochs = 50
    batch_size = 32

    history = model.fit(
        X_train, y_train_cat,
        validation_data=(X_val, y_val_cat),
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    densenet.history = history

    # Step 6: Evaluate on validation set
    print("\n" + "="*50)
    print("STEP 6: Validation Set Evaluation")
    print("="*50)

    # Predictions on validation set
    val_pred_probs = model.predict(X_val)
    val_pred_encoded = np.argmax(val_pred_probs, axis=1)

    # Calculate metrics for validation
    val_metrics = calculate_metrics(y_val_encoded, val_pred_encoded)

    print("Validation Metrics:")
    for metric, value in val_metrics.items():
        print(f"{metric.replace('_', ' ').title()}: {value:.4f}")

    # Step 7: Evaluate on test set
    print("\n" + "="*50)
    print("STEP 7: Test Set Evaluation")
    print("="*50)

    # Predictions on test set
    test_pred_probs = model.predict(X_test)
    test_pred_encoded = np.argmax(test_pred_probs, axis=1)

    # Calculate metrics for test
    test_metrics = calculate_metrics(y_test_encoded, test_pred_encoded)

    print("Test Metrics:")
    for metric, value in test_metrics.items():
        print(f"{metric.replace('_', ' ').title()}: {value:.4f}")

    # Step 8: Create visualizations
    print("\n" + "="*50)
    print("STEP 8: Creating Visualizations")
    print("="*50)

    # Class labels
    class_labels = ['very_low', 'low', 'medium', 'high', 'very_high']

    # Plot training history
    print("Plotting training history...")
    plot_training_history(history)

    # Plot confusion matrix for validation
    print("Plotting confusion matrix for validation...")
    plot_confusion_matrix(
        y_val_encoded, val_pred_encoded,
        class_labels,
        'Confusion Matrix - Validation Set'
    )

    # Plot confusion matrix for test
    print("Plotting confusion matrix for test...")
    plot_confusion_matrix(
        y_test_encoded, test_pred_encoded,
        class_labels,
        'Confusion Matrix - Test Set'
    )

    # Step 9: Detailed classification reports
    print("\n" + "="*50)
    print("STEP 9: Detailed Classification Reports")
    print("="*50)

    print("Validation Classification Report:")
    print(classification_report(y_val_encoded, val_pred_encoded,
                              target_names=class_labels))

    print("\nTest Classification Report:")
    print(classification_report(y_test_encoded, test_pred_encoded,
                              target_names=class_labels))

    # Step 10: Final summary
    print("\n" + "="*50)
    print("STEP 10: Final Summary")
    print("="*50)

    print("Final Results Summary:")
    print(f"Validation Accuracy: {val_metrics['accuracy']:.4f}")
    print(f"Validation Macro F1-Score: {val_metrics['macro_f1']:.4f}")
    print(f"Test Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Test Macro F1-Score: {test_metrics['macro_f1']:.4f}")

    return densenet, history, val_metrics, test_metrics

# Run the complete pipeline
if __name__ == "__main__":
    # Execute the main pipeline
    model, training_history, validation_metrics, test_metrics = main()

    print("\nTraining completed successfully!")
    print("Model is ready for inference on new data.")
# Out:
# ==================================================
# STEP 1: Loading and Preprocessing Data
# ==================================================
# Loading datasets...
# Train dataset shape: (3584, 84)
# Validation dataset shape: (768, 84)
# Test dataset shape: (768, 84)
#
# Missing values in train dataset:
# 0
#
# ==================================================
# STEP 2: Initializing DenseNet Model
# ==================================================
#
# ==================================================
# STEP 3: Preprocessing Datasets
# ==================================================
# Training data shape: (3584, 83)
# Validation data shape: (768, 83)
# Test data shape: (768, 83)
#
# ==================================================
# STEP 4: Building and Compiling Model
# ==================================================
# Model Architecture:
# Model: "DenseNet_Tabular"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)  │ (None, 83)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial_dense       │ (None, 64)        │      5,376 │ input[0][0]       │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial_bn          │ (None, 64)        │        256 │ initial_dense[0]… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ initial_dropout     │ (None, 64)        │          0 │ initial_bn[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_bn_0  │ (None, 64)        │        256 │ initial_dropout[… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_relu… │ (None, 64)        │          0 │ dense_block_1_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_dens… │ (None, 32)        │      2,080 │ dense_block_1_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_conc… │ (None, 96)        │          0 │ initial_dropout[… │
# │ (Concatenate)       │                   │            │ dense_block_1_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_bn_1  │ (None, 96)        │        384 │ dense_block_1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_relu… │ (None, 96)        │          0 │ dense_block_1_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_dens… │ (None, 32)        │      3,104 │ dense_block_1_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_conc… │ (None, 128)       │          0 │ dense_block_1_co… │
# │ (Concatenate)       │                   │            │ dense_block_1_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_bn_2  │ (None, 128)       │        512 │ dense_block_1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_relu… │ (None, 128)       │          0 │ dense_block_1_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_dens… │ (None, 32)        │      4,128 │ dense_block_1_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_conc… │ (None, 160)       │          0 │ dense_block_1_co… │
# │ (Concatenate)       │                   │            │ dense_block_1_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_bn_3  │ (None, 160)       │        640 │ dense_block_1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_relu… │ (None, 160)       │          0 │ dense_block_1_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_dens… │ (None, 32)        │      5,152 │ dense_block_1_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_1_conc… │ (None, 192)       │          0 │ dense_block_1_co… │
# │ (Concatenate)       │                   │            │ dense_block_1_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_1_bn     │ (None, 192)       │        768 │ dense_block_1_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_1_relu   │ (None, 192)       │          0 │ transition_1_bn[… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_1_dense  │ (None, 96)        │     18,528 │ transition_1_rel… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_1_dropo… │ (None, 96)        │          0 │ transition_1_den… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_bn_0  │ (None, 96)        │        384 │ transition_1_dro… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_relu… │ (None, 96)        │          0 │ dense_block_2_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_dens… │ (None, 32)        │      3,104 │ dense_block_2_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_conc… │ (None, 128)       │          0 │ transition_1_dro… │
# │ (Concatenate)       │                   │            │ dense_block_2_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_bn_1  │ (None, 128)       │        512 │ dense_block_2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_relu… │ (None, 128)       │          0 │ dense_block_2_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_dens… │ (None, 32)        │      4,128 │ dense_block_2_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_conc… │ (None, 160)       │          0 │ dense_block_2_co… │
# │ (Concatenate)       │                   │            │ dense_block_2_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_bn_2  │ (None, 160)       │        640 │ dense_block_2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_relu… │ (None, 160)       │          0 │ dense_block_2_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_dens… │ (None, 32)        │      5,152 │ dense_block_2_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_conc… │ (None, 192)       │          0 │ dense_block_2_co… │
# │ (Concatenate)       │                   │            │ dense_block_2_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_bn_3  │ (None, 192)       │        768 │ dense_block_2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_relu… │ (None, 192)       │          0 │ dense_block_2_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_dens… │ (None, 32)        │      6,176 │ dense_block_2_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_2_conc… │ (None, 224)       │          0 │ dense_block_2_co… │
# │ (Concatenate)       │                   │            │ dense_block_2_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_2_bn     │ (None, 224)       │        896 │ dense_block_2_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_2_relu   │ (None, 224)       │          0 │ transition_2_bn[… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_2_dense  │ (None, 112)       │     25,200 │ transition_2_rel… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transition_2_dropo… │ (None, 112)       │          0 │ transition_2_den… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_bn_0  │ (None, 112)       │        448 │ transition_2_dro… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_relu… │ (None, 112)       │          0 │ dense_block_3_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_dens… │ (None, 32)        │      3,616 │ dense_block_3_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_conc… │ (None, 144)       │          0 │ transition_2_dro… │
# │ (Concatenate)       │                   │            │ dense_block_3_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_bn_1  │ (None, 144)       │        576 │ dense_block_3_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_relu… │ (None, 144)       │          0 │ dense_block_3_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_dens… │ (None, 32)        │      4,640 │ dense_block_3_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_conc… │ (None, 176)       │          0 │ dense_block_3_co… │
# │ (Concatenate)       │                   │            │ dense_block_3_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_bn_2  │ (None, 176)       │        704 │ dense_block_3_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_relu… │ (None, 176)       │          0 │ dense_block_3_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_dens… │ (None, 32)        │      5,664 │ dense_block_3_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_conc… │ (None, 208)       │          0 │ dense_block_3_co… │
# │ (Concatenate)       │                   │            │ dense_block_3_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_bn_3  │ (None, 208)       │        832 │ dense_block_3_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_relu… │ (None, 208)       │          0 │ dense_block_3_bn… │
# │ (ReLU)              │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_dens… │ (None, 32)        │      6,688 │ dense_block_3_re… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_block_3_conc… │ (None, 240)       │          0 │ dense_block_3_co… │
# │ (Concatenate)       │                   │            │ dense_block_3_de… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_bn            │ (None, 240)       │        960 │ dense_block_3_co… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_relu (ReLU)   │ (None, 240)       │          0 │ final_bn[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense_1  │ (None, 128)       │     30,848 │ final_relu[0][0]  │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dropout… │ (None, 128)       │          0 │ classifier_dense… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dense_2  │ (None, 64)        │      8,256 │ classifier_dropo… │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier_dropout… │ (None, 64)        │          0 │ classifier_dense… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ output (Dense)      │ (None, 5)         │        325 │ classifier_dropo… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 151,701 (592.58 KB)
#  Trainable params: 146,933 (573.96 KB)
#  Non-trainable params: 4,768 (18.62 KB)
# ==================================================
# STEP 5: Training the Model
# ==================================================
# Epoch 1/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.2211 - loss: 1.6589 - val_accuracy: 0.4010 - val_loss: 1.4463 - learning_rate: 0.0010
# Epoch 2/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.3667 - loss: 1.4410 - val_accuracy: 0.5065 - val_loss: 1.1611 - learning_rate: 0.0010
# Epoch 3/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4606 - loss: 1.2537 - val_accuracy: 0.5859 - val_loss: 0.9676 - learning_rate: 0.0010
# Epoch 4/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5438 - loss: 1.0816 - val_accuracy: 0.6380 - val_loss: 0.8940 - learning_rate: 0.0010
# Epoch 5/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5667 - loss: 1.0098 - val_accuracy: 0.6875 - val_loss: 0.7897 - learning_rate: 0.0010
# Epoch 6/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6160 - loss: 0.9135 - val_accuracy: 0.7018 - val_loss: 0.7237 - learning_rate: 0.0010
# Epoch 7/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.6479 - loss: 0.8515 - val_accuracy: 0.7240 - val_loss: 0.7210 - learning_rate: 0.0010
# Epoch 8/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.6812 - loss: 0.7889 - val_accuracy: 0.7604 - val_loss: 0.6297 - learning_rate: 0.0010
# Epoch 9/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.6999 - loss: 0.7485 - val_accuracy: 0.7734 - val_loss: 0.6105 - learning_rate: 0.0010
# Epoch 10/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7208 - loss: 0.6981 - val_accuracy: 0.7695 - val_loss: 0.6218 - learning_rate: 0.0010
# Epoch 11/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7478 - loss: 0.6767 - val_accuracy: 0.7721 - val_loss: 0.6184 - learning_rate: 0.0010
# Epoch 12/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.7662 - loss: 0.6282 - val_accuracy: 0.7982 - val_loss: 0.5715 - learning_rate: 0.0010
# Epoch 13/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7616 - loss: 0.6094 - val_accuracy: 0.7995 - val_loss: 0.5545 - learning_rate: 0.0010
# Epoch 14/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.7812 - loss: 0.5913 - val_accuracy: 0.7812 - val_loss: 0.6061 - learning_rate: 0.0010
# Epoch 15/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7937 - loss: 0.5438 - val_accuracy: 0.7969 - val_loss: 0.6167 - learning_rate: 0.0010
# Epoch 16/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.7898 - loss: 0.5628 - val_accuracy: 0.7799 - val_loss: 0.6497 - learning_rate: 0.0010
# Epoch 17/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8152 - loss: 0.4907 - val_accuracy: 0.7995 - val_loss: 0.5957 - learning_rate: 0.0010
# Epoch 18/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8296 - loss: 0.4539 - val_accuracy: 0.8021 - val_loss: 0.5907 - learning_rate: 0.0010
# Epoch 19/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8409 - loss: 0.4470 - val_accuracy: 0.8099 - val_loss: 0.5926 - learning_rate: 5.0000e-04
# Epoch 20/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8474 - loss: 0.4013 - val_accuracy: 0.8138 - val_loss: 0.6068 - learning_rate: 5.0000e-04
# Epoch 21/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.8473 - loss: 0.4135 - val_accuracy: 0.8151 - val_loss: 0.5915 - learning_rate: 5.0000e-04
# Epoch 22/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.8737 - loss: 0.3569 - val_accuracy: 0.8099 - val_loss: 0.6287 - learning_rate: 5.0000e-04
# Epoch 23/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8617 - loss: 0.3788 - val_accuracy: 0.8229 - val_loss: 0.5956 - learning_rate: 5.0000e-04
# Epoch 24/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8757 - loss: 0.3381 - val_accuracy: 0.8177 - val_loss: 0.5865 - learning_rate: 2.5000e-04
# Epoch 25/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8761 - loss: 0.3390 - val_accuracy: 0.8125 - val_loss: 0.5786 - learning_rate: 2.5000e-04
# Epoch 26/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.8803 - loss: 0.3139 - val_accuracy: 0.8099 - val_loss: 0.6138 - learning_rate: 2.5000e-04
# Epoch 27/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8868 - loss: 0.2902 - val_accuracy: 0.8203 - val_loss: 0.6069 - learning_rate: 2.5000e-04
# Epoch 28/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.8907 - loss: 0.2930 - val_accuracy: 0.8229 - val_loss: 0.6087 - learning_rate: 2.5000e-04
# Epoch 29/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8857 - loss: 0.3114 - val_accuracy: 0.8203 - val_loss: 0.5921 - learning_rate: 1.2500e-04
# Epoch 30/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8984 - loss: 0.2708 - val_accuracy: 0.8255 - val_loss: 0.6010 - learning_rate: 1.2500e-04
# Epoch 31/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9007 - loss: 0.2689 - val_accuracy: 0.8242 - val_loss: 0.6007 - learning_rate: 1.2500e-04
# Epoch 32/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9099 - loss: 0.2504 - val_accuracy: 0.8268 - val_loss: 0.6255 - learning_rate: 1.2500e-04
# Epoch 33/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.9071 - loss: 0.2811 - val_accuracy: 0.8268 - val_loss: 0.6270 - learning_rate: 1.2500e-04
# Epoch 34/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9068 - loss: 0.2672 - val_accuracy: 0.8281 - val_loss: 0.6236 - learning_rate: 6.2500e-05
# Epoch 35/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9100 - loss: 0.2397 - val_accuracy: 0.8281 - val_loss: 0.6310 - learning_rate: 6.2500e-05
# Epoch 36/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9099 - loss: 0.2406 - val_accuracy: 0.8307 - val_loss: 0.6351 - learning_rate: 6.2500e-05
# Epoch 37/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9138 - loss: 0.2483 - val_accuracy: 0.8294 - val_loss: 0.6322 - learning_rate: 6.2500e-05
# Epoch 38/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9099 - loss: 0.2531 - val_accuracy: 0.8229 - val_loss: 0.6381 - learning_rate: 6.2500e-05
# Epoch 39/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9138 - loss: 0.2290 - val_accuracy: 0.8216 - val_loss: 0.6391 - learning_rate: 3.1250e-05
# Epoch 40/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9238 - loss: 0.2384 - val_accuracy: 0.8216 - val_loss: 0.6433 - learning_rate: 3.1250e-05
# Epoch 41/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9226 - loss: 0.2196 - val_accuracy: 0.8255 - val_loss: 0.6476 - learning_rate: 3.1250e-05
# Epoch 42/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9146 - loss: 0.2285 - val_accuracy: 0.8242 - val_loss: 0.6433 - learning_rate: 3.1250e-05
# Epoch 43/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9218 - loss: 0.2197 - val_accuracy: 0.8268 - val_loss: 0.6399 - learning_rate: 3.1250e-05
# Epoch 44/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9233 - loss: 0.2195 - val_accuracy: 0.8307 - val_loss: 0.6424 - learning_rate: 1.5625e-05
# Epoch 45/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9165 - loss: 0.2177 - val_accuracy: 0.8294 - val_loss: 0.6425 - learning_rate: 1.5625e-05
# Epoch 46/50
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9237 - loss: 0.2255 - val_accuracy: 0.8281 - val_loss: 0.6457 - learning_rate: 1.5625e-05
#
# ==================================================
# STEP 6: Validation Set Evaluation
# ==================================================
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Validation Metrics:
# Accuracy: 0.8307
# Precision: 0.8309
# Recall: 0.8307
# F1 Score: 0.8305
# Macro F1: 0.8299
#
# ==================================================
# STEP 7: Test Set Evaluation
# ==================================================
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Metrics:
# Accuracy: 0.8112
# Precision: 0.8130
# Recall: 0.8112
# F1 Score: 0.8116
# Macro F1: 0.8098
#
# ==================================================
# STEP 8: Creating Visualizations
# ==================================================
# Plotting training history...
# Plotting confusion matrix for validation...
# Plotting confusion matrix for test...
# ==================================================
# STEP 9: Detailed Classification Reports
# ==================================================
# Validation Classification Report:
#               precision    recall  f1-score   support
#
#     very_low       0.79      0.74      0.76       157
#          low       0.81      0.86      0.83       147
#       medium       0.75      0.76      0.76       153
#         high       0.85      0.87      0.86       151
#    very_high       0.95      0.93      0.94       160
#
#     accuracy                           0.83       768
#    macro avg       0.83      0.83      0.83       768
# weighted avg       0.83      0.83      0.83       768
#
#
# Test Classification Report:
#               precision    recall  f1-score   support
#
#     very_low       0.75      0.76      0.76       136
#          low       0.77      0.76      0.76       151
#       medium       0.76      0.78      0.77       163
#         high       0.92      0.84      0.88       167
#    very_high       0.86      0.90      0.88       151
#
#     accuracy                           0.81       768
#    macro avg       0.81      0.81      0.81       768
# weighted avg       0.81      0.81      0.81       768
#
#
# ==================================================
# STEP 10: Final Summary
# ==================================================
# Final Results Summary:
# Validation Accuracy: 0.8307
# Validation Macro F1-Score: 0.8299
# Test Accuracy: 0.8112
# Test Macro F1-Score: 0.8098
#
# Training completed successfully!
# Model is ready for inference on new data.
