# %%
# -*- coding: utf-8 -*-
# RNN for Crop Production Classification (5 Classes)

# This script demonstrates how to build and train a Recurrent Neural Network (RNN)
# for classifying crop production levels into 5 classes based on tabular data using TensorFlow/Keras.

## 1. Setup and Imports

# Import necessary libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, f1_score
import matplotlib.pyplot as plt
import seaborn as sns

# Define file paths for session upload
TRAIN_PATH = "train.csv"
VALID_PATH = "validation.csv"
TEST_PATH = "test.csv"

## 2. Load and Preprocess Data

def load_and_preprocess(file_path, scaler=None, fit_scaler=False, label_encoder=None, fit_encoder=False):
    """Loads data, preprocesses features, and converts target to 5 classes."""
    df = pd.read_csv(file_path)

    # Define class boundaries based on quantiles for 5 classes
    # Using 20%, 40%, 60%, and 80% quantiles for even distribution
    if fit_scaler:  # Only compute quantiles on training data
        quantiles = np.quantile(df["Production (M.Ton)"], [0.2, 0.4, 0.6, 0.8])
        feature_scaler = StandardScaler()
    else:
        # These will be provided from training data
        if scaler is None:
            raise ValueError("Scaler must be provided if fit_scaler is False")
        quantiles, feature_scaler = scaler  # Unpack the tuple of (quantiles, feature_scaler)

    # Create class labels based on quantiles
    bins = [-np.inf, quantiles[0], quantiles[1], quantiles[2], quantiles[3], np.inf]
    labels = ["very low", "low", "medium", "high", "very high"]

    # Convert target variable to classes
    df["Production_Category"] = pd.cut(df["Production (M.Ton)"], bins=bins, labels=labels, right=True)

    # Separate features and target
    X = df.drop(["Production (M.Ton)", "Production_Category"], axis=1)
    y = df["Production_Category"]

    # Identify numerical features (excluding one-hot encoded Crop and District)
    # Assuming columns starting with 'Crop_' or 'District_' are one-hot encoded
    numerical_cols = [col for col in X.columns if not col.startswith("Crop_") and not col.startswith("District_")]

    # Scale numerical features
    if fit_scaler:
        X[numerical_cols] = feature_scaler.fit_transform(X[numerical_cols])
    else:
        X[numerical_cols] = feature_scaler.transform(X[numerical_cols])

    # Encode labels
    if fit_encoder:
        le = LabelEncoder()
        y_encoded = le.fit_transform(y)
    else:
        if label_encoder is None:
            raise ValueError("LabelEncoder must be provided if fit_encoder is False")
        y_encoded = label_encoder.transform(y)

    # Convert labels to one-hot encoding
    y_one_hot = tf.keras.utils.to_categorical(y_encoded, num_classes=len(labels))

    # For RNN, reshape features to sequence format: (samples, timesteps, features)
    # We'll treat each feature as a timestep in a sequence
    X_reshaped = X.values.reshape((X.shape[0], X.shape[1], 1))

    if fit_scaler and fit_encoder:
        return X_reshaped, y_one_hot, (quantiles, feature_scaler), le
    elif fit_scaler:
         return X_reshaped, y_one_hot, (quantiles, feature_scaler)
    elif fit_encoder:
        return X_reshaped, y_one_hot, label_encoder
    else:
        return X_reshaped, y_one_hot

# Load and preprocess data
print("Loading and preprocessing training data...")
X_train, y_train, scalers, label_encoder = load_and_preprocess(TRAIN_PATH, fit_scaler=True, fit_encoder=True)

print("Loading and preprocessing validation data...")
X_val, y_val = load_and_preprocess(VALID_PATH, scaler=scalers, label_encoder=label_encoder)

print("Loading and preprocessing test data...")
X_test, y_test = load_and_preprocess(TEST_PATH, scaler=scalers, label_encoder=label_encoder)

quantiles, feature_scaler = scalers

print(f"Training data shape: {X_train.shape}, Labels shape: {y_train.shape}")
print(f"Validation data shape: {X_val.shape}, Labels shape: {y_val.shape}")
print(f"Test data shape: {X_test.shape}, Labels shape: {y_test.shape}")
print(f"Number of classes: {y_train.shape[1]}")
print(f"Class boundaries (quantiles): {quantiles}")
print(f"Class names: {label_encoder.classes_}")

## 3. Build the RNN Model

def build_rnn_model(input_shape, num_classes):
    """Builds the RNN model for tabular data classification."""
    model = keras.Sequential([
        # Input layer
        keras.Input(shape=input_shape),

        # RNN layers
        layers.SimpleRNN(64, return_sequences=True),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        layers.SimpleRNN(128),
        layers.BatchNormalization(),
        layers.Dropout(0.3),

        # Dense layers for classification
        layers.Dense(64, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_classes, activation='softmax')
    ])

    return model

# Get input shape and number of classes from preprocessed data
input_shape = (X_train.shape[1], X_train.shape[2])  # (timesteps, features)
num_classes = y_train.shape[1]  # 5 classes

# Build the model
model = build_rnn_model(input_shape, num_classes)

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

# Print model summary
model.summary()

## 4. Train the Model

# Define training parameters
EPOCHS = 100
BATCH_SIZE = 64

# Add Early Stopping to prevent overfitting
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=15,
    restore_best_weights=True
)

# Train the model
history = model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=[early_stopping]
)

## 5. Evaluate the Model

# Get best validation accuracy from history
if 'val_accuracy' in history.history:
    best_val_accuracy = max(history.history['val_accuracy'])
    print(f"\nBest Validation Accuracy: {best_val_accuracy:.4f}")
else:
    print("\nValidation accuracy not available in history.")

# Evaluate the trained model on the test dataset
print("\nEvaluating model on test data...")
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")

# Generate predictions
print("\nGenerating predictions on test data...")
y_pred_proba = model.predict(X_test)
y_pred = np.argmax(y_pred_proba, axis=1)

# Convert one-hot encoded y_test back to single labels for comparison
y_test_labels = np.argmax(y_test, axis=1)

# Print Classification Report (includes Recall and F1-score per class, and macro/weighted averages)
print("\nClassification Report (includes Recall and F1-score):")
print(classification_report(y_test_labels, y_pred, target_names=label_encoder.classes_))

# Calculate and print Macro F1 Score separately
macro_f1 = f1_score(y_test_labels, y_pred, average='macro')
print(f"\nMacro F1 Score (Test Set): {macro_f1:.4f}")

# Print Confusion Matrix
print("\nConfusion Matrix:")
cm = confusion_matrix(y_test_labels, y_pred)
print(cm)

## 6. Visualize Results

# Plot training history and confusion matrix

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"])
if 'val_accuracy' in history.history:
    plt.plot(history.history["val_accuracy"])
    plt.legend(["Train", "Validation"], loc="upper left")
else:
    plt.legend(["Train"], loc="upper left")
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"])
if 'val_loss' in history.history:
    plt.plot(history.history["val_loss"])
    plt.legend(["Train", "Validation"], loc="upper left")
else:
    plt.legend(["Train"], loc="upper left")
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.tight_layout()
plt.show()

# Plot Confusion Matrix Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_encoder.classes_,
            yticklabels=label_encoder.classes_)
plt.title("Confusion Matrix")
plt.ylabel("True Label")
plt.xlabel("Predicted Label")
plt.show()

print("\n--- End of Script ---")
# Out:
# Loading and preprocessing training data...
# Loading and preprocessing validation data...
# Loading and preprocessing test data...
# Training data shape: (3584, 83, 1), Labels shape: (3584, 5)
# Validation data shape: (768, 83, 1), Labels shape: (768, 5)
# Test data shape: (768, 83, 1), Labels shape: (768, 5)
# Number of classes: 5
# Class boundaries (quantiles): [ 550.2   1447.52  3064.522 6362.6  ]
# Class names: ['high' 'low' 'medium' 'very high' 'very low']
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 83, 64)         │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 83, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 83, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_1 (SimpleRNN)        │ (None, 128)            │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 5)              │           325 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,277 (149.52 KB)
#  Trainable params: 37,893 (148.02 KB)
#  Non-trainable params: 384 (1.50 KB)
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 15s 100ms/step - accuracy: 0.2342 - loss: 2.0995 - val_accuracy: 0.3164 - val_loss: 1.4900
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.3024 - loss: 1.7319 - val_accuracy: 0.3151 - val_loss: 1.5115
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.3186 - loss: 1.6348 - val_accuracy: 0.3828 - val_loss: 1.3790
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 94ms/step - accuracy: 0.3491 - loss: 1.5259 - val_accuracy: 0.4167 - val_loss: 1.3616
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.3928 - loss: 1.4396 - val_accuracy: 0.3633 - val_loss: 1.3920
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.4109 - loss: 1.3910 - val_accuracy: 0.4857 - val_loss: 1.2060
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.4117 - loss: 1.3192 - val_accuracy: 0.5052 - val_loss: 1.1535
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.4577 - loss: 1.2696 - val_accuracy: 0.5312 - val_loss: 1.1358
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.4707 - loss: 1.2279 - val_accuracy: 0.5286 - val_loss: 1.0935
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.4929 - loss: 1.1536 - val_accuracy: 0.5208 - val_loss: 1.1027
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.5021 - loss: 1.1428 - val_accuracy: 0.5443 - val_loss: 1.0544
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.4780 - loss: 1.1831 - val_accuracy: 0.5286 - val_loss: 1.0600
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.5205 - loss: 1.1204 - val_accuracy: 0.5521 - val_loss: 1.0436
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.5283 - loss: 1.1165 - val_accuracy: 0.5781 - val_loss: 1.0157
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.5547 - loss: 1.0816 - val_accuracy: 0.5612 - val_loss: 0.9784
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.5585 - loss: 1.0527 - val_accuracy: 0.5807 - val_loss: 0.9736
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5361 - loss: 1.0990 - val_accuracy: 0.5846 - val_loss: 1.0044
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.5352 - loss: 1.0607 - val_accuracy: 0.6081 - val_loss: 0.9313
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.5674 - loss: 1.0208 - val_accuracy: 0.6068 - val_loss: 0.9152
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5885 - loss: 0.9791 - val_accuracy: 0.5833 - val_loss: 0.9691
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.5928 - loss: 0.9953 - val_accuracy: 0.6224 - val_loss: 0.8876
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.6138 - loss: 0.9255 - val_accuracy: 0.6380 - val_loss: 0.8734
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.5878 - loss: 0.9968 - val_accuracy: 0.6510 - val_loss: 0.8782
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - accuracy: 0.6163 - loss: 0.9231 - val_accuracy: 0.6263 - val_loss: 0.8814
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6347 - loss: 0.9007 - val_accuracy: 0.6719 - val_loss: 0.8288
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6274 - loss: 0.8741 - val_accuracy: 0.6393 - val_loss: 0.8374
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.6324 - loss: 0.8893 - val_accuracy: 0.6758 - val_loss: 0.7930
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6424 - loss: 0.8738 - val_accuracy: 0.6836 - val_loss: 0.7672
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6649 - loss: 0.8254 - val_accuracy: 0.6745 - val_loss: 0.8043
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 91ms/step - accuracy: 0.6429 - loss: 0.8623 - val_accuracy: 0.7083 - val_loss: 0.7165
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.6650 - loss: 0.8298 - val_accuracy: 0.6979 - val_loss: 0.7754
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6636 - loss: 0.8315 - val_accuracy: 0.6849 - val_loss: 0.7743
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.6680 - loss: 0.8113 - val_accuracy: 0.7240 - val_loss: 0.7002
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.6769 - loss: 0.8005 - val_accuracy: 0.7083 - val_loss: 0.7467
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.6777 - loss: 0.8017 - val_accuracy: 0.6966 - val_loss: 0.7328
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.6672 - loss: 0.8002 - val_accuracy: 0.6979 - val_loss: 0.7630
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.6786 - loss: 0.8018 - val_accuracy: 0.7135 - val_loss: 0.6927
# Epoch 38/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step - accuracy: 0.6947 - loss: 0.7544 - val_accuracy: 0.7227 - val_loss: 0.6918
# Epoch 39/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.6914 - loss: 0.7639 - val_accuracy: 0.7474 - val_loss: 0.6801
# Epoch 40/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7064 - loss: 0.7139 - val_accuracy: 0.7044 - val_loss: 0.7438
# Epoch 41/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.7006 - loss: 0.7277 - val_accuracy: 0.7344 - val_loss: 0.6750
# Epoch 42/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.7041 - loss: 0.7126 - val_accuracy: 0.7331 - val_loss: 0.6976
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7254 - loss: 0.7091 - val_accuracy: 0.7695 - val_loss: 0.6017
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.7270 - loss: 0.6839 - val_accuracy: 0.7591 - val_loss: 0.6372
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7307 - loss: 0.6700 - val_accuracy: 0.7435 - val_loss: 0.6496
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.7237 - loss: 0.6689 - val_accuracy: 0.7799 - val_loss: 0.6258
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - accuracy: 0.7217 - loss: 0.6792 - val_accuracy: 0.7526 - val_loss: 0.6208
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7287 - loss: 0.6949 - val_accuracy: 0.7552 - val_loss: 0.6760
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.7470 - loss: 0.6598 - val_accuracy: 0.7513 - val_loss: 0.6208
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 82ms/step - accuracy: 0.7620 - loss: 0.6352 - val_accuracy: 0.7786 - val_loss: 0.6166
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - accuracy: 0.7302 - loss: 0.6599 - val_accuracy: 0.7773 - val_loss: 0.6079
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7374 - loss: 0.6464 - val_accuracy: 0.7383 - val_loss: 0.6805
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 87ms/step - accuracy: 0.7294 - loss: 0.6676 - val_accuracy: 0.7760 - val_loss: 0.5902
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7630 - loss: 0.6037 - val_accuracy: 0.7370 - val_loss: 0.7402
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - accuracy: 0.7269 - loss: 0.6795 - val_accuracy: 0.7617 - val_loss: 0.5987
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.7447 - loss: 0.6618 - val_accuracy: 0.7513 - val_loss: 0.6102
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.7466 - loss: 0.6640 - val_accuracy: 0.7643 - val_loss: 0.6255
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - accuracy: 0.7435 - loss: 0.6508 - val_accuracy: 0.7695 - val_loss: 0.6101
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.7638 - loss: 0.6065 - val_accuracy: 0.7656 - val_loss: 0.5952
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7542 - loss: 0.6244 - val_accuracy: 0.7826 - val_loss: 0.5754
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.7741 - loss: 0.5895 - val_accuracy: 0.7786 - val_loss: 0.5951
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.7508 - loss: 0.6147 - val_accuracy: 0.7604 - val_loss: 0.6048
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7632 - loss: 0.6040 - val_accuracy: 0.7656 - val_loss: 0.6938
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7644 - loss: 0.6269 - val_accuracy: 0.7448 - val_loss: 0.6767
# Epoch 65/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.7633 - loss: 0.6152 - val_accuracy: 0.7760 - val_loss: 0.6032
# Epoch 66/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.7768 - loss: 0.5604 - val_accuracy: 0.7760 - val_loss: 0.5886
# Epoch 67/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.7800 - loss: 0.5881 - val_accuracy: 0.7969 - val_loss: 0.5823
# Epoch 68/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 92ms/step - accuracy: 0.7632 - loss: 0.6099 - val_accuracy: 0.7747 - val_loss: 0.6005
# Epoch 69/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - accuracy: 0.7679 - loss: 0.5774 - val_accuracy: 0.7786 - val_loss: 0.5706
# Epoch 70/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7682 - loss: 0.5643 - val_accuracy: 0.7669 - val_loss: 0.5996
# Epoch 71/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7592 - loss: 0.6536 - val_accuracy: 0.7539 - val_loss: 0.6306
# Epoch 72/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.7716 - loss: 0.5987 - val_accuracy: 0.7799 - val_loss: 0.5831
# Epoch 73/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 77ms/step - accuracy: 0.7858 - loss: 0.5482 - val_accuracy: 0.7474 - val_loss: 0.6203
# Epoch 74/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - accuracy: 0.7922 - loss: 0.5512 - val_accuracy: 0.7826 - val_loss: 0.5586
# Epoch 75/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 94ms/step - accuracy: 0.7677 - loss: 0.5750 - val_accuracy: 0.7878 - val_loss: 0.6113
# Epoch 76/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7725 - loss: 0.5812 - val_accuracy: 0.7786 - val_loss: 0.5620
# Epoch 77/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7728 - loss: 0.5729 - val_accuracy: 0.7826 - val_loss: 0.5918
# Epoch 78/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - accuracy: 0.7685 - loss: 0.5680 - val_accuracy: 0.7669 - val_loss: 0.6133
# Epoch 79/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7626 - loss: 0.6320 - val_accuracy: 0.7734 - val_loss: 0.6208
# Epoch 80/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.7671 - loss: 0.6038 - val_accuracy: 0.7812 - val_loss: 0.5600
# Epoch 81/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.7915 - loss: 0.5548 - val_accuracy: 0.7839 - val_loss: 0.6006
# Epoch 82/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7500 - loss: 0.6363 - val_accuracy: 0.7773 - val_loss: 0.5989
# Epoch 83/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.7748 - loss: 0.6064 - val_accuracy: 0.7734 - val_loss: 0.5771
# Epoch 84/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - accuracy: 0.7889 - loss: 0.5579 - val_accuracy: 0.7760 - val_loss: 0.5907
# Epoch 85/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - accuracy: 0.7979 - loss: 0.5292 - val_accuracy: 0.7982 - val_loss: 0.5599
# Epoch 86/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 93ms/step - accuracy: 0.7912 - loss: 0.5219 - val_accuracy: 0.7969 - val_loss: 0.5503
# Epoch 87/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.7826 - loss: 0.5465 - val_accuracy: 0.7747 - val_loss: 0.5959
# Epoch 88/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 82ms/step - accuracy: 0.7809 - loss: 0.5605 - val_accuracy: 0.7747 - val_loss: 0.5679
# Epoch 89/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.7900 - loss: 0.5224 - val_accuracy: 0.7904 - val_loss: 0.5937
# Epoch 90/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 86ms/step - accuracy: 0.7975 - loss: 0.5128 - val_accuracy: 0.7826 - val_loss: 0.5722
# Epoch 91/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.8033 - loss: 0.4887 - val_accuracy: 0.7812 - val_loss: 0.6147
# Epoch 92/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.7557 - loss: 0.6361 - val_accuracy: 0.7591 - val_loss: 0.6043
# Epoch 93/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 6s 89ms/step - accuracy: 0.7541 - loss: 0.6205 - val_accuracy: 0.7839 - val_loss: 0.5739
# Epoch 94/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7697 - loss: 0.5792 - val_accuracy: 0.7930 - val_loss: 0.5739
# Epoch 95/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8045 - loss: 0.5213 - val_accuracy: 0.7865 - val_loss: 0.5548
# Epoch 96/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 90ms/step - accuracy: 0.7947 - loss: 0.5252 - val_accuracy: 0.8099 - val_loss: 0.5307
# Epoch 97/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.8177 - loss: 0.4797 - val_accuracy: 0.7747 - val_loss: 0.5924
# Epoch 98/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7855 - loss: 0.5713 - val_accuracy: 0.7826 - val_loss: 0.5697
# Epoch 99/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 89ms/step - accuracy: 0.7806 - loss: 0.5558 - val_accuracy: 0.7865 - val_loss: 0.5696
# Epoch 100/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.8022 - loss: 0.5385 - val_accuracy: 0.7747 - val_loss: 0.5445
#
# Best Validation Accuracy: 0.8099
#
# Evaluating model on test data...
# Test Loss: 0.6332
# Test Accuracy: 0.7891
#
# Generating predictions on test data...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# Classification Report (includes Recall and F1-score):
#               precision    recall  f1-score   support
#
#         high       0.74      0.65      0.69       136
#          low       0.74      0.75      0.74       151
#       medium       0.74      0.79      0.76       163
#    very high       0.85      0.85      0.85       167
#     very low       0.87      0.89      0.88       151
#
#     accuracy                           0.79       768
#    macro avg       0.79      0.79      0.79       768
# weighted avg       0.79      0.79      0.79       768
#
#
# Macro F1 Score (Test Set): 0.7850
#
# Confusion Matrix:
# [[ 88   6  21  20   1]
#  [  3 113  17   1  17]
#  [  9  18 128   5   3]
#  [ 19   1   5 142   0]
#  [  0  15   1   0 135]]
# --- End of Script ---
