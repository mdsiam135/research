# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/ResNet(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, BatchNormalization, ReLU, Add, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("Step 1: Libraries imported successfully!")

# Step 2: Load and preprocess data
def load_and_preprocess_data():
    """Load and preprocess the CSV files"""
    print("\nStep 2: Loading data...")

    # Load CSV files
    train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
    val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')

    print(f"Train data shape: {train_df.shape}")
    print(f"Validation data shape: {val_df.shape}")
    print(f"Test data shape: {test_df.shape}")

    return train_df, val_df, test_df

# Step 3: Create quantile-based labels
def create_quantile_labels(train_df, val_df, test_df):
    """Create quantile-based labels for production"""
    print("\nStep 3: Creating quantile-based labels...")

    # Calculate quantiles based on training data
    production_col = 'Production (M.Ton)'
    quantiles = train_df[production_col].quantile([0.2, 0.4, 0.6, 0.8]).values

    print(f"Quantile thresholds: {quantiles}")

    def assign_labels(production_values, quantiles):
        labels = []
        for val in production_values:
            if val <= quantiles[0]:
                labels.append(0)  # Very Low
            elif val <= quantiles[1]:
                labels.append(1)  # Low
            elif val <= quantiles[2]:
                labels.append(2)  # Medium
            elif val <= quantiles[3]:
                labels.append(3)  # High
            else:
                labels.append(4)  # Very High
        return np.array(labels)

    # Create labels for all datasets
    y_train = assign_labels(train_df[production_col], quantiles)
    y_val = assign_labels(val_df[production_col], quantiles)
    y_test = assign_labels(test_df[production_col], quantiles)

    # Print label distribution
    label_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    print("\nLabel distribution:")
    for i, name in enumerate(label_names):
        print(f"{name}: Train={np.sum(y_train==i)}, Val={np.sum(y_val==i)}, Test={np.sum(y_test==i)}")

    return y_train, y_val, y_test, quantiles

# Step 4: Prepare features
def prepare_features(train_df, val_df, test_df):
    """Prepare feature matrices"""
    print("\nStep 4: Preparing features...")

    # Drop the target column
    feature_cols = [col for col in train_df.columns if col != 'Production (M.Ton)']

    X_train = train_df[feature_cols].values
    X_val = val_df[feature_cols].values
    X_test = test_df[feature_cols].values

    # Handle missing values
    X_train = np.nan_to_num(X_train)
    X_val = np.nan_to_num(X_val)
    X_test = np.nan_to_num(X_test)

    # Standardize features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    print(f"Feature matrix shapes:")
    print(f"X_train: {X_train_scaled.shape}")
    print(f"X_val: {X_val_scaled.shape}")
    print(f"X_test: {X_test_scaled.shape}")

    return X_train_scaled, X_val_scaled, X_test_scaled, scaler

# Step 5: Build ResNet model
def residual_block(x, units, dropout_rate=0.2):
    """Create a residual block"""
    # Save input for skip connection
    shortcut = x

    # First layer
    x = Dense(units)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)

    # Second layer
    x = Dense(units)(x)
    x = BatchNormalization()(x)

    # Adjust shortcut dimensions if needed
    if shortcut.shape[-1] != units:
        shortcut = Dense(units)(shortcut)

    # Add skip connection
    x = Add()([x, shortcut])
    x = ReLU()(x)
    x = Dropout(dropout_rate)(x)

    return x

def build_resnet_model(input_dim, num_classes=5):
    """Build ResNet model for classification"""
    print("\nStep 5: Building ResNet model...")

    # Input layer
    inputs = Input(shape=(input_dim,))

    # Initial dense layer
    x = Dense(256)(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.3)(x)

    # Residual blocks
    x = residual_block(x, 512, 0.3)
    x = residual_block(x, 512, 0.3)
    x = residual_block(x, 256, 0.2)
    x = residual_block(x, 256, 0.2)
    x = residual_block(x, 128, 0.2)

    # Final layers
    x = Dense(64)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    x = Dropout(0.2)(x)

    # Output layer
    outputs = Dense(num_classes, activation='softmax')(x)

    # Create model
    model = Model(inputs=inputs, outputs=outputs)

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("Model architecture:")
    model.summary()

    return model

# Step 6: Train the model
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the ResNet model"""
    print(f"\nStep 6: Training model for {epochs} epochs...")

    # Convert labels to categorical
    y_train_cat = to_categorical(y_train, 5)
    y_val_cat = to_categorical(y_val, 5)

    # Callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    )

    # Train model
    history = model.fit(
        X_train, y_train_cat,
        validation_data=(X_val, y_val_cat),
        epochs=epochs,
        batch_size=32,
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    return history

# Step 7: Evaluation functions
def calculate_metrics(y_true, y_pred):
    """Calculate classification metrics"""
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')
    f1_macro = f1_score(y_true, y_pred, average='macro')

    return {
        'Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1 Score (Weighted)': f1_weighted,
        'F1 Score (Macro)': f1_macro
    }

def plot_confusion_matrix(y_true, y_pred, title, dataset_name):
    """Plot confusion matrix"""
    cm = confusion_matrix(y_true, y_pred)
    labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title(f'{title} - {dataset_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.tight_layout()
    plt.show()

    return cm

def plot_training_history(history):
    """Plot training and validation accuracy/loss"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy', marker='o')
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', marker='s')
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss', marker='o')
    ax2.plot(history.history['val_loss'], label='Validation Loss', marker='s')
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True)

    plt.tight_layout()
    plt.show()

# Step 8: Main execution function
def main():
    """Main execution function"""
    try:
        # Load data
        train_df, val_df, test_df = load_and_preprocess_data()

        # Create labels
        y_train, y_val, y_test, quantiles = create_quantile_labels(train_df, val_df, test_df)

        # Prepare features
        X_train, X_val, X_test, scaler = prepare_features(train_df, val_df, test_df)

        # Build model
        model = build_resnet_model(X_train.shape[1])

        # Train model
        history = train_model(model, X_train, y_train, X_val, y_val, epochs=100)

        # Plot training history
        plot_training_history(history)

        # Make predictions
        print("\nStep 7: Making predictions...")
        y_val_pred = np.argmax(model.predict(X_val), axis=1)
        y_test_pred = np.argmax(model.predict(X_test), axis=1)

        # Calculate metrics for validation set
        print("\n" + "="*50)
        print("VALIDATION SET RESULTS")
        print("="*50)
        val_metrics = calculate_metrics(y_val, y_val_pred)
        for metric, value in val_metrics.items():
            print(f"{metric}: {value:.4f}")

        # Calculate metrics for test set
        print("\n" + "="*50)
        print("TEST SET RESULTS")
        print("="*50)
        test_metrics = calculate_metrics(y_test, y_test_pred)
        for metric, value in test_metrics.items():
            print(f"{metric}: {value:.4f}")

        # Plot confusion matrices
        print("\nStep 8: Plotting confusion matrices...")
        val_cm = plot_confusion_matrix(y_val, y_val_pred, "Confusion Matrix", "Validation Set")
        test_cm = plot_confusion_matrix(y_test, y_test_pred, "Confusion Matrix", "Test Set")

        # Detailed classification report
        print("\n" + "="*50)
        print("DETAILED CLASSIFICATION REPORT - VALIDATION")
        print("="*50)
        labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
        print(classification_report(y_val, y_val_pred, target_names=labels))

        print("\n" + "="*50)
        print("DETAILED CLASSIFICATION REPORT - TEST")
        print("="*50)
        print(classification_report(y_test, y_test_pred, target_names=labels))

        # Summary
        print("\n" + "="*60)
        print("FINAL SUMMARY")
        print("="*60)
        print(f"Model trained successfully!")
        print(f"Validation Accuracy: {val_metrics['Accuracy']:.4f}")
        print(f"Validation Macro F1: {val_metrics['F1 Score (Macro)']:.4f}")
        print(f"Test Accuracy: {test_metrics['Accuracy']:.4f}")
        print(f"Test Macro F1: {test_metrics['F1 Score (Macro)']:.4f}")

        return model, history, val_metrics, test_metrics, scaler

    except FileNotFoundError as e:
        print(f"Error: Could not find CSV files. Please ensure train.csv, validation.csv, and test.csv are in the current directory.")
        print(f"Error details: {e}")
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# Step 9: Run the complete pipeline
if __name__ == "__main__":
    print("Starting ResNet Crop Production Classification Pipeline")
    print("="*60)

    # Execute main function
    results = main()

    if results:
        model, history, val_metrics, test_metrics, scaler = results
        print("\nPipeline completed successfully!")

        # Save model if needed
        # model.save('resnet_crop_production_model.h5')
        # print("Model saved as 'resnet_crop_production_model.h5'")
    else:
        print("Pipeline failed. Please check your data files and try again.")
# Out:
# Step 1: Libraries imported successfully!
# Starting ResNet Crop Production Classification Pipeline
# ============================================================
#
# Step 2: Loading data...
# Train data shape: (3584, 84)
# Validation data shape: (768, 84)
# Test data shape: (768, 84)
#
# Step 3: Creating quantile-based labels...
# Quantile thresholds: [ 550.2   1447.52  3064.522 6362.6  ]
#
# Label distribution:
# Very Low: Train=717, Val=160, Test=151
# Low: Train=717, Val=147, Test=151
# Medium: Train=716, Val=153, Test=163
# High: Train=717, Val=157, Test=136
# Very High: Train=717, Val=151, Test=167
#
# Step 4: Preparing features...
# Feature matrix shapes:
# X_train: (3584, 83)
# X_val: (768, 83)
# X_test: (768, 83)
#
# Step 5: Building ResNet model...
# Model architecture:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 83)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_64 (Dense)    │ (None, 256)       │     21,504 │ input_layer_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_64[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_48 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_48          │ (None, 256)       │          0 │ re_lu_48[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_65 (Dense)    │ (None, 512)       │    131,584 │ dropout_48[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_65[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_49 (ReLU)     │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_49          │ (None, 512)       │          0 │ re_lu_49[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_66 (Dense)    │ (None, 512)       │    262,656 │ dropout_49[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_66[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_67 (Dense)    │ (None, 512)       │    131,584 │ dropout_48[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dense_67[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_50 (ReLU)     │ (None, 512)       │          0 │ add_20[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_50          │ (None, 512)       │          0 │ re_lu_50[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_68 (Dense)    │ (None, 512)       │    262,656 │ dropout_50[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_68[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_51 (ReLU)     │ (None, 512)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_51          │ (None, 512)       │          0 │ re_lu_51[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_69 (Dense)    │ (None, 512)       │    262,656 │ dropout_51[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 512)       │      2,048 │ dense_69[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 512)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_50[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_52 (ReLU)     │ (None, 512)       │          0 │ add_21[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_52          │ (None, 512)       │          0 │ re_lu_52[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_70 (Dense)    │ (None, 256)       │    131,328 │ dropout_52[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_70[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_53 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_53          │ (None, 256)       │          0 │ re_lu_53[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_71 (Dense)    │ (None, 256)       │     65,792 │ dropout_53[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_71[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_72 (Dense)    │ (None, 256)       │    131,328 │ dropout_52[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dense_72[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_54 (ReLU)     │ (None, 256)       │          0 │ add_22[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 256)       │          0 │ re_lu_54[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_73 (Dense)    │ (None, 256)       │     65,792 │ dropout_54[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_73[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_55 (ReLU)     │ (None, 256)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 256)       │          0 │ re_lu_55[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_74 (Dense)    │ (None, 256)       │     65,792 │ dropout_55[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_74[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ dropout_54[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_56 (ReLU)     │ (None, 256)       │          0 │ add_23[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_56          │ (None, 256)       │          0 │ re_lu_56[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_75 (Dense)    │ (None, 128)       │     32,896 │ dropout_56[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128)       │        512 │ dense_75[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_57 (ReLU)     │ (None, 128)       │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout
# Epoch 25/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.8494 - loss: 0.4188 - val_accuracy: 0.8307 - val_loss: 0.4800 - learning_rate: 0.0010
# Epoch 26/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8566 - loss: 0.4004 - val_accuracy: 0.8398 - val_loss: 0.4684 - learning_rate: 0.0010
# Epoch 27/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.8491 - loss: 0.4076 - val_accuracy: 0.8333 - val_loss: 0.5141 - learning_rate: 0.0010
# Epoch 28/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8458 - loss: 0.4000 - val_accuracy: 0.8372 - val_loss: 0.4788 - learning_rate: 0.0010
# Epoch 29/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - accuracy: 0.8636 - loss: 0.3798 - val_accuracy: 0.8438 - val_loss: 0.4680 - learning_rate: 0.0010
# Epoch 30/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8815 - loss: 0.3351 - val_accuracy: 0.8411 - val_loss: 0.4921 - learning_rate: 0.0010
# Epoch 31/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.8805 - loss: 0.3538 - val_accuracy: 0.8451 - val_loss: 0.4563 - learning_rate: 0.0010
# Epoch 32/100
# 111/112 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8767 - loss: 0.3341
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - accuracy: 0.8767 - loss: 0.3341 - val_accuracy: 0.8385 - val_loss: 0.5085 - learning_rate: 0.0010
# Epoch 33/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.8920 - loss: 0.3316 - val_accuracy: 0.8594 - val_loss: 0.4638 - learning_rate: 5.0000e-04
# Epoch 34/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 36ms/step - accuracy: 0.8942 - loss: 0.2784 - val_accuracy: 0.8555 - val_loss: 0.4562 - learning_rate: 5.0000e-04
# Epoch 35/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - accuracy: 0.8931 - loss: 0.2925 - val_accuracy: 0.8516 - val_loss: 0.4699 - learning_rate: 5.0000e-04
# Epoch 36/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.9132 - loss: 0.2528 - val_accuracy: 0.8411 - val_loss: 0.4901 - learning_rate: 5.0000e-04
# Epoch 37/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.9110 - loss: 0.2552 - val_accuracy: 0.8385 - val_loss: 0.5091 - learning_rate: 5.0000e-04
# Epoch 38/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 4s 40ms/step - accuracy: 0.9115 - loss: 0.2613 - val_accuracy: 0.8516 - val_loss: 0.4904 - learning_rate: 5.0000e-04
# Epoch 39/100
# 112/112 ━━━━━━━━━━━━━━━━━━━━ 5s 34ms/step - accuracy: 0.9039 - loss: 0.2629 - val_accuracy: 0.8607 - val_loss: 0.4831 - learning_rate: 5.0000e-04
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Step 7: Making predictions...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# ==================================================
# VALIDATION SET RESULTS
# ==================================================
# Accuracy: 0.8438
# Precision: 0.8443
# Recall: 0.8438
# F1 Score (Weighted): 0.8438
# F1 Score (Macro): 0.8432
#
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.8138
# Precision: 0.8161
# Recall: 0.8138
# F1 Score (Weighted): 0.8130
# F1 Score (Macro): 0.8106
#
# Step 8: Plotting confusion matrices...
# ==================================================
# DETAILED CLASSIFICATION REPORT - VALIDATION
# ==================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.95      0.93      0.94       160
#          Low       0.84      0.81      0.83       147
#       Medium       0.77      0.80      0.79       153
#         High       0.79      0.77      0.78       157
#    Very High       0.86      0.90      0.88       151
#
#     accuracy                           0.84       768
#    macro avg       0.84      0.84      0.84       768
# weighted avg       0.84      0.84      0.84       768
#
#
# ==================================================
# DETAILED CLASSIFICATION REPORT - TEST
# ==================================================
#               precision    recall  f1-score   support
#
#     Very Low       0.88      0.91      0.90       151
#          Low       0.80      0.70      0.74       151
#       Medium       0.71      0.83      0.76       163
#         High       0.79      0.71      0.75       136
#    Very High       0.90      0.90      0.90       167
#
#     accuracy                           0.81       768
#    macro avg       0.82      0.81      0.81       768
# weighted avg       0.82      0.81      0.81       768
#
#
# ============================================================
# FINAL SUMMARY
# ============================================================
# Model trained successfully!
# Validation Accuracy: 0.8438
# Validation Macro F1: 0.8432
# Test Accuracy: 0.8138
# Test Macro F1: 0.8106
#
# Pipeline completed successfully!
