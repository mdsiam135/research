# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/Improved_MLP(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("Libraries imported successfully!")

# Step 2: Load and Prepare Data
def load_and_prepare_data():
    """Load CSV files and prepare data for training"""

    # Load datasets
    try:
        train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
        val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
        test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')
        print(f"Data loaded successfully!")
        print(f"Train shape: {train_df.shape}")
        print(f"Validation shape: {val_df.shape}")
        print(f"Test shape: {test_df.shape}")
    except FileNotFoundError as e:
        print(f"Error loading files: {e}")
        return None, None, None, None, None, None

    # Combine all data to calculate quantiles consistently
    all_data = pd.concat([train_df, val_df, test_df], ignore_index=True)

    # Create quantile-based labels for production
    production_col = 'Production (M.Ton)'
    quantiles = all_data[production_col].quantile([0.2, 0.4, 0.6, 0.8]).values

    def create_production_labels(production_values):
        labels = []
        for val in production_values:
            if val <= quantiles[0]:
                labels.append('very low')
            elif val <= quantiles[1]:
                labels.append('low')
            elif val <= quantiles[2]:
                labels.append('medium')
            elif val <= quantiles[3]:
                labels.append('high')
            else:
                labels.append('very high')
        return labels

    # Apply labels to each dataset
    train_df['production_label'] = create_production_labels(train_df[production_col])
    val_df['production_label'] = create_production_labels(val_df[production_col])
    test_df['production_label'] = create_production_labels(test_df[production_col])

    print("\nProduction label distribution:")
    print("Training:", train_df['production_label'].value_counts().sort_index())
    print("Validation:", val_df['production_label'].value_counts().sort_index())
    print("Testing:", test_df['production_label'].value_counts().sort_index())

    # Separate features and labels
    feature_cols = [col for col in train_df.columns if col not in [production_col, 'production_label']]

    X_train = train_df[feature_cols].values
    X_val = val_df[feature_cols].values
    X_test = test_df[feature_cols].values

    # Encode labels
    label_encoder = LabelEncoder()
    all_labels = np.concatenate([train_df['production_label'], val_df['production_label'], test_df['production_label']])
    label_encoder.fit(all_labels)

    y_train = label_encoder.transform(train_df['production_label'])
    y_val = label_encoder.transform(val_df['production_label'])
    y_test = label_encoder.transform(test_df['production_label'])

    # Convert to categorical for neural network
    num_classes = len(label_encoder.classes_)
    y_train_cat = to_categorical(y_train, num_classes)
    y_val_cat = to_categorical(y_val, num_classes)
    y_test_cat = to_categorical(y_test, num_classes)

    print(f"\nFeature shape: {X_train.shape[1]}")
    print(f"Number of classes: {num_classes}")
    print(f"Classes: {label_encoder.classes_}")

    return X_train, X_val, X_test, y_train_cat, y_val_cat, y_test_cat, y_train, y_val, y_test, label_encoder

# Step 3: Preprocess Data
def preprocess_data(X_train, X_val, X_test):
    """Standardize features"""
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    print("Data preprocessing completed!")
    return X_train_scaled, X_val_scaled, X_test_scaled, scaler

# Step 4: Build Improved MLP Model
def build_improved_mlp(input_shape, num_classes, dropout_rate=0.4):
    """Build improved MLP with BatchNorm, Dropout, and multiple hidden layers"""

    model = Sequential([
        # Input layer
        Dense(512, input_shape=(input_shape,)),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 1
        Dense(256),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 2
        Dense(128),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 3
        Dense(64),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 4
        Dense(32),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate * 0.5),  # Reduced dropout for deeper layers

        # Output layer
        Dense(num_classes, activation='softmax')
    ])

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("Model architecture:")
    model.summary()

    return model

# Step 5: Train Model
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the model with callbacks"""

    # Define callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    )

    # Train model
    print(f"\nStarting training for {epochs} epochs...")
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    print("Training completed!")
    return history

# Step 6: Evaluation Functions
def calculate_metrics(y_true, y_pred, label_encoder):
    """Calculate comprehensive metrics"""

    accuracy = accuracy_score(y_true, y_pred)
    precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
    precision_weighted = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
    recall_weighted = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    metrics = {
        'Accuracy': accuracy,
        'Precision (Macro)': precision_macro,
        'Precision (Weighted)': precision_weighted,
        'Recall (Macro)': recall_macro,
        'Recall (Weighted)': recall_weighted,
        'F1 Score (Macro)': f1_macro,
        'F1 Score (Weighted)': f1_weighted
    }

    return metrics

def plot_confusion_matrix(y_true, y_pred, label_encoder, title, dataset_name):
    """Plot confusion matrix"""

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(5, 3))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=label_encoder.classes_,
                yticklabels=label_encoder.classes_)
    plt.title(f'{title} - {dataset_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

def plot_training_history(history):
    """Plot training and validation accuracy/loss"""

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss', linewidth=2)
    ax2.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Step 7: Main Execution Function
def main():
    """Main execution function"""

    print("=== Improved MLP Model for Production Classification ===\n")

    # Load and prepare data
    data_results = load_and_prepare_data()
    if data_results[0] is None:
        return

    X_train, X_val, X_test, y_train_cat, y_val_cat, y_test_cat, y_train, y_val, y_test, label_encoder = data_results

    # Preprocess data
    X_train_scaled, X_val_scaled, X_test_scaled, scaler = preprocess_data(X_train, X_val, X_test)

    # Build model
    model = build_improved_mlp(X_train_scaled.shape[1], len(label_encoder.classes_))

    # Train model
    history = train_model(model, X_train_scaled, y_train_cat, X_val_scaled, y_val_cat, epochs=100)

    # Plot training history
    plot_training_history(history)

    # Make predictions
    print("\nMaking predictions...")

    # Validation predictions
    y_val_pred_probs = model.predict(X_val_scaled)
    y_val_pred = np.argmax(y_val_pred_probs, axis=1)

    # Test predictions
    y_test_pred_probs = model.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_probs, axis=1)

    # Calculate metrics for validation set
    print("\n" + "="*50)
    print("VALIDATION SET RESULTS")
    print("="*50)

    val_metrics = calculate_metrics(y_val, y_val_pred, label_encoder)
    for metric, value in val_metrics.items():
        print(f"{metric}: {value:.4f}")

    # Calculate metrics for test set
    print("\n" + "="*50)
    print("TEST SET RESULTS")
    print("="*50)

    test_metrics = calculate_metrics(y_test, y_test_pred, label_encoder)
    for metric, value in test_metrics.items():
        print(f"{metric}: {value:.4f}")

    # Plot confusion matrices
    print("\nGenerating confusion matrices...")
    plot_confusion_matrix(y_val, y_val_pred, label_encoder,
                         "Confusion Matrix", "Validation Set")

    plot_confusion_matrix(y_test, y_test_pred, label_encoder,
                         "Confusion Matrix", "Test Set")

    # Classification reports
    print("\n" + "="*50)
    print("DETAILED CLASSIFICATION REPORT - VALIDATION SET")
    print("="*50)
    print(classification_report(y_val, y_val_pred,
                              target_names=label_encoder.classes_))

    print("\n" + "="*50)
    print("DETAILED CLASSIFICATION REPORT - TEST SET")
    print("="*50)
    print(classification_report(y_test, y_test_pred,
                              target_names=label_encoder.classes_))

    # Summary comparison
    print("\n" + "="*50)
    print("SUMMARY COMPARISON")
    print("="*50)
    print(f"{'Metric':<20} {'Validation':<12} {'Test':<12}")
    print("-" * 50)

    comparison_metrics = ['Accuracy', 'F1 Score (Macro)', 'F1 Score (Weighted)']
    for metric in comparison_metrics:
        print(f"{metric:<20} {val_metrics[metric]:<12.4f} {test_metrics[metric]:<12.4f}")

    return model, history, val_metrics, test_metrics

# Run the complete pipeline
if __name__ == "__main__":
    model, history, val_metrics, test_metrics = main()
# Out:
# Libraries imported successfully!
# === Improved MLP Model for Production Classification ===
#
# Data loaded successfully!
# Train shape: (3584, 84)
# Validation shape: (768, 84)
# Test shape: (768, 84)
#
# Production label distribution:
# Training: production_label
# high         728
# low          725
# medium       709
# very high    708
# very low     714
# Name: count, dtype: int64
# Validation: production_label
# high         159
# low          147
# medium       153
# very high    149
# very low     160
# Name: count, dtype: int64
# Testing: production_label
# high         136
# low          153
# medium       162
# very high    167
# very low     150
# Name: count, dtype: int64
#
# Feature shape: 83
# Number of classes: 5
# Classes: ['high' 'low' 'medium' 'very high' 'very low']
# Data preprocessing completed!
# Model architecture:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │        43,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_3 (LeakyReLU)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_4 (LeakyReLU)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221,701 (866.02 KB)
#  Trainable params: 219,717 (858.27 KB)
#  Non-trainable params: 1,984 (7.75 KB)
# Starting training for 100 epochs...
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 39ms/step - accuracy: 0.2277 - loss: 2.0093 - val_accuracy: 0.4036 - val_loss: 1.5081 - learning_rate: 0.0010
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.2873 - loss: 1.6485 - val_accuracy: 0.5013 - val_loss: 1.3590 - learning_rate: 0.0010
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.3496 - loss: 1.4639 - val_accuracy: 0.5365 - val_loss: 1.1913 - learning_rate: 0.0010
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.4038 - loss: 1.3546 - val_accuracy: 0.5612 - val_loss: 1.0737 - learning_rate: 0.0010
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.4665 - loss: 1.2265 - val_accuracy: 0.5911 - val_loss: 0.9955 - learning_rate: 0.0010
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4996 - loss: 1.1518 - val_accuracy: 0.6380 - val_loss: 0.9187 - learning_rate: 0.0010
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5469 - loss: 1.0683 - val_accuracy: 0.6523 - val_loss: 0.8626 - learning_rate: 0.0010
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.
- val_loss: 0.4514 - learning_rate: 0.0010
# Epoch 43/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.8466 - loss: 0.4357 - val_accuracy: 0.8451 - val_loss: 0.4357 - learning_rate: 0.0010
# Epoch 44/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8532 - loss: 0.4033 - val_accuracy: 0.8398 - val_loss: 0.4362 - learning_rate: 0.0010
# Epoch 45/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8661 - loss: 0.3715 - val_accuracy: 0.8464 - val_loss: 0.4178 - learning_rate: 0.0010
# Epoch 46/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8615 - loss: 0.4027 - val_accuracy: 0.8503 - val_loss: 0.4249 - learning_rate: 0.0010
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8683 - loss: 0.3803 - val_accuracy: 0.8424 - val_loss: 0.4356 - learning_rate: 0.0010
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8513 - loss: 0.4160 - val_accuracy: 0.8307 - val_loss: 0.4626 - learning_rate: 0.0010
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8743 - loss: 0.3849 - val_accuracy: 0.8372 - val_loss: 0.4502 - learning_rate: 0.0010
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8678 - loss: 0.3947 - val_accuracy: 0.8490 - val_loss: 0.4338 - learning_rate: 0.0010
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8684 - loss: 0.3700 - val_accuracy: 0.8372 - val_loss: 0.4536 - learning_rate: 0.0010
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8744 - loss: 0.3625 - val_accuracy: 0.8451 - val_loss: 0.4391 - learning_rate: 0.0010
# Epoch 53/100
# 52/56 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8773 - loss: 0.3621
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8772 - loss: 0.3625 - val_accuracy: 0.8398 - val_loss: 0.4677 - learning_rate: 0.0010
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8791 - loss: 0.3608 - val_accuracy: 0.8542 - val_loss: 0.4366 - learning_rate: 5.0000e-04
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8866 - loss: 0.3517 - val_accuracy: 0.8516 - val_loss: 0.4202 - learning_rate: 5.0000e-04
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8869 - loss: 0.3158 - val_accuracy: 0.8490 - val_loss: 0.4187 - learning_rate: 5.0000e-04
# Epoch 57/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8925 - loss: 0.3102 - val_accuracy: 0.8503 - val_loss: 0.4308 - learning_rate: 5.0000e-04
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8976 - loss: 0.3017 - val_accuracy: 0.8568 - val_loss: 0.4219 - learning_rate: 5.0000e-04
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8874 - loss: 0.3245 - val_accuracy: 0.8555 - val_loss: 0.4383 - learning_rate: 5.0000e-04
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.8966 - loss: 0.3088 - val_accuracy: 0.8568 - val_loss: 0.4323 - learning_rate: 5.0000e-04
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 45.
# Training completed!
# Making predictions...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# ==================================================
# VALIDATION SET RESULTS
# ==================================================
# Accuracy: 0.8464
# Precision (Macro): 0.8493
# Precision (Weighted): 0.8490
# Recall (Macro): 0.8459
# Recall (Weighted): 0.8464
# F1 Score (Macro): 0.8470
# F1 Score (Weighted): 0.8471
#
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.8138
# Precision (Macro): 0.8174
# Precision (Weighted): 0.8200
# Recall (Macro): 0.8126
# Recall (Weighted): 0.8138
# F1 Score (Macro): 0.8122
# F1 Score (Weighted): 0.8140
#
# Generating confusion matrices...
# ==================================================
# DETAILED CLASSIFICATION REPORT - VALIDATION SET
# ==================================================
#               precision    recall  f1-score   support
#
#         high       0.75      0.82      0.78       159
#          low       0.87      0.82      0.84       147
#       medium       0.81      0.79      0.80       153
#    very high       0.87      0.89      0.88       149
#     very low       0.94      0.91      0.93       160
#
#     accuracy                           0.85       768
#    macro avg       0.85      0.85      0.85       768
# weighted avg       0.85      0.85      0.85       768
#
#
# ==================================================
# DETAILED CLASSIFICATION REPORT - TEST SET
# ==================================================
#               precision    recall  f1-score   support
#
#         high       0.73      0.78      0.75       136
#          low       0.83      0.68      0.75       153
#       medium       0.72      0.82      0.76       162
#    very high       0.93      0.86      0.89       167
#     very low       0.89      0.93      0.91       150
#
#     accuracy                           0.81       768
#    macro avg       0.82      0.81      0.81       768
# weighted avg       0.82      0.81      0.81       768
#
#
# ==================================================
# SUMMARY COMPARISON
# ==================================================
# Metric               Validation   Test
# --------------------------------------------------
# Accuracy             0.8464       0.8138
# F1 Score (Macro)     0.8470       0.8122
# F1 Score (Weighted)  0.8471       0.8140
