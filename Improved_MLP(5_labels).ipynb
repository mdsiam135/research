# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/Improved_MLP(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Import Required Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

print("Libraries imported successfully!")

# Step 2: Load and Prepare Data
def load_and_prepare_data():
    """Load CSV files and prepare data for training"""

    # Load datasets
    try:
        train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
        val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
        test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')
        print(f"Data loaded successfully!")
        print(f"Train shape: {train_df.shape}")
        print(f"Validation shape: {val_df.shape}")
        print(f"Test shape: {test_df.shape}")
    except FileNotFoundError as e:
        print(f"Error loading files: {e}")
        return None, None, None, None, None, None

    # Combine all data to calculate quantiles consistently
    all_data = pd.concat([train_df, val_df, test_df], ignore_index=True)

    # Create quantile-based labels for production
    production_col = 'Production (M.Ton)'
    quantiles = all_data[production_col].quantile([0.2, 0.4, 0.6, 0.8]).values

    def create_production_labels(production_values):
        labels = []
        for val in production_values:
            if val <= quantiles[0]:
                labels.append('very low')
            elif val <= quantiles[1]:
                labels.append('low')
            elif val <= quantiles[2]:
                labels.append('medium')
            elif val <= quantiles[3]:
                labels.append('high')
            else:
                labels.append('very high')
        return labels

    # Apply labels to each dataset
    train_df['production_label'] = create_production_labels(train_df[production_col])
    val_df['production_label'] = create_production_labels(val_df[production_col])
    test_df['production_label'] = create_production_labels(test_df[production_col])

    print("\nProduction label distribution:")
    print("Training:", train_df['production_label'].value_counts().sort_index())
    print("Validation:", val_df['production_label'].value_counts().sort_index())
    print("Testing:", test_df['production_label'].value_counts().sort_index())

    # Separate features and labels
    feature_cols = [col for col in train_df.columns if col not in [production_col, 'production_label']]

    X_train = train_df[feature_cols].values
    X_val = val_df[feature_cols].values
    X_test = test_df[feature_cols].values

    # Encode labels
    label_encoder = LabelEncoder()
    all_labels = np.concatenate([train_df['production_label'], val_df['production_label'], test_df['production_label']])
    label_encoder.fit(all_labels)

    y_train = label_encoder.transform(train_df['production_label'])
    y_val = label_encoder.transform(val_df['production_label'])
    y_test = label_encoder.transform(test_df['production_label'])

    # Convert to categorical for neural network
    num_classes = len(label_encoder.classes_)
    y_train_cat = to_categorical(y_train, num_classes)
    y_val_cat = to_categorical(y_val, num_classes)
    y_test_cat = to_categorical(y_test, num_classes)

    print(f"\nFeature shape: {X_train.shape[1]}")
    print(f"Number of classes: {num_classes}")
    print(f"Classes: {label_encoder.classes_}")

    return X_train, X_val, X_test, y_train_cat, y_val_cat, y_test_cat, y_train, y_val, y_test, label_encoder

# Step 3: Preprocess Data
def preprocess_data(X_train, X_val, X_test):
    """Standardize features"""
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    print("Data preprocessing completed!")
    return X_train_scaled, X_val_scaled, X_test_scaled, scaler

# Step 4: Build Improved MLP Model
def build_improved_mlp(input_shape, num_classes, dropout_rate=0.4):
    """Build improved MLP with BatchNorm, Dropout, and multiple hidden layers"""

    model = Sequential([
        # Input layer
        Dense(512, input_shape=(input_shape,)),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 1
        Dense(256),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 2
        Dense(128),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 3
        Dense(64),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate),

        # Hidden layer 4
        Dense(32),
        BatchNormalization(),
        tf.keras.layers.LeakyReLU(alpha=0.01),
        Dropout(dropout_rate * 0.5),  # Reduced dropout for deeper layers

        # Output layer
        Dense(num_classes, activation='softmax')
    ])

    # Compile model
    model.compile(
        optimizer=Adam(learning_rate=0.001),
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    print("Model architecture:")
    model.summary()

    return model

# Step 5: Train Model
def train_model(model, X_train, y_train, X_val, y_val, epochs=100):
    """Train the model with callbacks"""

    # Define callbacks
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    )

    # Train model
    print(f"\nStarting training for {epochs} epochs...")
    history = model.fit(
        X_train, y_train,
        epochs=epochs,
        batch_size=64,
        validation_data=(X_val, y_val),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    print("Training completed!")
    return history

# Step 6: Evaluation Functions
def calculate_metrics(y_true, y_pred, label_encoder):
    """Calculate comprehensive metrics"""

    accuracy = accuracy_score(y_true, y_pred)
    precision_macro = precision_score(y_true, y_pred, average='macro', zero_division=0)
    precision_weighted = precision_score(y_true, y_pred, average='weighted', zero_division=0)
    recall_macro = recall_score(y_true, y_pred, average='macro', zero_division=0)
    recall_weighted = recall_score(y_true, y_pred, average='weighted', zero_division=0)
    f1_macro = f1_score(y_true, y_pred, average='macro', zero_division=0)
    f1_weighted = f1_score(y_true, y_pred, average='weighted', zero_division=0)

    metrics = {
        'Accuracy': accuracy,
        'Precision (Macro)': precision_macro,
        'Precision (Weighted)': precision_weighted,
        'Recall (Macro)': recall_macro,
        'Recall (Weighted)': recall_weighted,
        'F1 Score (Macro)': f1_macro,
        'F1 Score (Weighted)': f1_weighted
    }

    return metrics

def plot_confusion_matrix(y_true, y_pred, label_encoder, title, dataset_name):
    """Plot confusion matrix"""

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=label_encoder.classes_,
                yticklabels=label_encoder.classes_)
    plt.title(f'{title} - {dataset_name}')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.xticks(rotation=45)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

def plot_training_history(history):
    """Plot training and validation accuracy/loss"""

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    # Plot accuracy
    ax1.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    ax1.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    ax1.set_title('Model Accuracy')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Accuracy')
    ax1.legend()
    ax1.grid(True, alpha=0.3)

    # Plot loss
    ax2.plot(history.history['loss'], label='Training Loss', linewidth=2)
    ax2.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    ax2.set_title('Model Loss')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Loss')
    ax2.legend()
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()

# Step 7: Main Execution Function
def main():
    """Main execution function"""

    print("=== Improved MLP Model for Production Classification ===\n")

    # Load and prepare data
    data_results = load_and_prepare_data()
    if data_results[0] is None:
        return

    X_train, X_val, X_test, y_train_cat, y_val_cat, y_test_cat, y_train, y_val, y_test, label_encoder = data_results

    # Preprocess data
    X_train_scaled, X_val_scaled, X_test_scaled, scaler = preprocess_data(X_train, X_val, X_test)

    # Build model
    model = build_improved_mlp(X_train_scaled.shape[1], len(label_encoder.classes_))

    # Train model
    history = train_model(model, X_train_scaled, y_train_cat, X_val_scaled, y_val_cat, epochs=100)

    # Plot training history
    plot_training_history(history)

    # Make predictions
    print("\nMaking predictions...")

    # Validation predictions
    y_val_pred_probs = model.predict(X_val_scaled)
    y_val_pred = np.argmax(y_val_pred_probs, axis=1)

    # Test predictions
    y_test_pred_probs = model.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_probs, axis=1)

    # Calculate metrics for validation set
    print("\n" + "="*50)
    print("VALIDATION SET RESULTS")
    print("="*50)

    val_metrics = calculate_metrics(y_val, y_val_pred, label_encoder)
    for metric, value in val_metrics.items():
        print(f"{metric}: {value:.4f}")

    # Calculate metrics for test set
    print("\n" + "="*50)
    print("TEST SET RESULTS")
    print("="*50)

    test_metrics = calculate_metrics(y_test, y_test_pred, label_encoder)
    for metric, value in test_metrics.items():
        print(f"{metric}: {value:.4f}")

    # Plot confusion matrices
    print("\nGenerating confusion matrices...")
    plot_confusion_matrix(y_val, y_val_pred, label_encoder,
                         "Confusion Matrix", "Validation Set")

    plot_confusion_matrix(y_test, y_test_pred, label_encoder,
                         "Confusion Matrix", "Test Set")

    # Classification reports
    print("\n" + "="*50)
    print("DETAILED CLASSIFICATION REPORT - VALIDATION SET")
    print("="*50)
    print(classification_report(y_val, y_val_pred,
                              target_names=label_encoder.classes_))

    print("\n" + "="*50)
    print("DETAILED CLASSIFICATION REPORT - TEST SET")
    print("="*50)
    print(classification_report(y_test, y_test_pred,
                              target_names=label_encoder.classes_))

    # Summary comparison
    print("\n" + "="*50)
    print("SUMMARY COMPARISON")
    print("="*50)
    print(f"{'Metric':<20} {'Validation':<12} {'Test':<12}")
    print("-" * 50)

    comparison_metrics = ['Accuracy', 'F1 Score (Macro)', 'F1 Score (Weighted)']
    for metric in comparison_metrics:
        print(f"{metric:<20} {val_metrics[metric]:<12.4f} {test_metrics[metric]:<12.4f}")

    return model, history, val_metrics, test_metrics

# Run the complete pipeline
if __name__ == "__main__":
    model, history, val_metrics, test_metrics = main()
# Out:
# Libraries imported successfully!
# === Improved MLP Model for Production Classification ===
#
# Data loaded successfully!
# Train shape: (3584, 84)
# Validation shape: (768, 84)
# Test shape: (768, 84)
#
# Production label distribution:
# Training: production_label
# high         728
# low          725
# medium       709
# very high    708
# very low     714
# Name: count, dtype: int64
# Validation: production_label
# high         159
# low          147
# medium       153
# very high    149
# very low     160
# Name: count, dtype: int64
# Testing: production_label
# high         136
# low          153
# medium       162
# very high    167
# very low     150
# Name: count, dtype: int64
#
# Feature shape: 83
# Number of classes: 5
# Classes: ['high' 'low' 'medium' 'very high' 'very low']
# Data preprocessing completed!
# Model architecture:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 512)            │        43,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_5 (LeakyReLU)       │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_6 (LeakyReLU)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_7 (LeakyReLU)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_8 (LeakyReLU)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_9 (LeakyReLU)       │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221,701 (866.02 KB)
#  Trainable params: 219,717 (858.27 KB)
#  Non-trainable params: 1,984 (7.75 KB)
# Starting training for 100 epochs...
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 16s 46ms/step - accuracy: 0.2201 - loss: 1.9304 - val_accuracy: 0.3802 - val_loss: 1.5311 - learning_rate: 0.0010
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.2661 - loss: 1.6564 - val_accuracy: 0.4701 - val_loss: 1.4055 - learning_rate: 0.0010
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3381 - loss: 1.5309 - val_accuracy: 0.5339 - val_loss: 1.2566 - learning_rate: 0.0010
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.3864 - loss: 1.4213 - val_accuracy: 0.5573 - val_loss: 1.1165 - learning_rate: 0.0010
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.4490 - loss: 1.2960 - val_accuracy: 0.5820 - val_loss: 1.0165 - learning_rate: 0.0010
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.4874 - loss: 1.2171 - val_accuracy: 0.5938 - val_loss: 0.9593 - learning_rate: 0.0010
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5188 - loss: 1.1212 - val_accuracy: 0.6120 - val_loss: 0.9046 - learning_rate: 0.0010
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5538 - loss: 1.0463 - val_accuracy: 0.6406 - val_loss: 0.8552 - learning_rate: 0.0010
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.5964 - loss: 1.0137 - val_accuracy: 0.6654 - val_loss: 0.8212 - learning_rate: 0.0010
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.5912 - loss: 0.9616 - val_accuracy: 0.6966 - val_loss: 0.7651 - learning_rate: 0.0010
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6234 - loss: 0.9193 - val_accuracy: 0.7214 - val_loss: 0.7331 - learning_rate: 0.0010
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.
# Epoch 47/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8716 - loss: 0.3671 - val_accuracy: 0.8477 - val_loss: 0.4189 - learning_rate: 5.0000e-04
# Epoch 48/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8786 - loss: 0.3635 - val_accuracy: 0.8529 - val_loss: 0.4081 - learning_rate: 5.0000e-04
# Epoch 49/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8797 - loss: 0.3568 - val_accuracy: 0.8490 - val_loss: 0.4004 - learning_rate: 5.0000e-04
# Epoch 50/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8739 - loss: 0.3731 - val_accuracy: 0.8398 - val_loss: 0.4257 - learning_rate: 5.0000e-04
# Epoch 51/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8802 - loss: 0.3689 - val_accuracy: 0.8398 - val_loss: 0.4217 - learning_rate: 5.0000e-04
# Epoch 52/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8826 - loss: 0.3389 - val_accuracy: 0.8372 - val_loss: 0.4320 - learning_rate: 5.0000e-04
# Epoch 53/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8821 - loss: 0.3518 - val_accuracy: 0.8385 - val_loss: 0.4309 - learning_rate: 5.0000e-04
# Epoch 54/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.8825 - loss: 0.3440 - val_accuracy: 0.8581 - val_loss: 0.4138 - learning_rate: 5.0000e-04
# Epoch 55/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8793 - loss: 0.3549 - val_accuracy: 0.8581 - val_loss: 0.4172 - learning_rate: 5.0000e-04
# Epoch 56/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8787 - loss: 0.3442 - val_accuracy: 0.8451 - val_loss: 0.4314 - learning_rate: 5.0000e-04
# Epoch 57/100
# 53/56 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8908 - loss: 0.3083
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8909 - loss: 0.3082 - val_accuracy: 0.8529 - val_loss: 0.4248 - learning_rate: 5.0000e-04
# Epoch 58/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8935 - loss: 0.3057 - val_accuracy: 0.8568 - val_loss: 0.4163 - learning_rate: 2.5000e-04
# Epoch 59/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8908 - loss: 0.3108 - val_accuracy: 0.8594 - val_loss: 0.4128 - learning_rate: 2.5000e-04
# Epoch 60/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.8978 - loss: 0.3146 - val_accuracy: 0.8568 - val_loss: 0.4123 - learning_rate: 2.5000e-04
# Epoch 61/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8953 - loss: 0.3094 - val_accuracy: 0.8490 - val_loss: 0.4169 - learning_rate: 2.5000e-04
# Epoch 62/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.8937 - loss: 0.3162 - val_accuracy: 0.8568 - val_loss: 0.4204 - learning_rate: 2.5000e-04
# Epoch 63/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8945 - loss: 0.3108 - val_accuracy: 0.8555 - val_loss: 0.4145 - learning_rate: 2.5000e-04
# Epoch 64/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8957 - loss: 0.2973 - val_accuracy: 0.8581 - val_loss: 0.4199 - learning_rate: 2.5000e-04
# Epoch 64: early stopping
# Restoring model weights from the end of the best epoch: 49.
# Training completed!
# Making predictions...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
# VALIDATION SET RESULTS
# ==================================================
# Accuracy: 0.8490
# Precision (Macro): 0.8494
# Precision (Weighted): 0.8500
# Recall (Macro): 0.8497
# Recall (Weighted): 0.8490
# F1 Score (Macro): 0.8487
# F1 Score (Weighted): 0.8486
#
# ==================================================
# TEST SET RESULTS
# ==================================================
# Accuracy: 0.8203
# Precision (Macro): 0.8216
# Precision (Weighted): 0.8231
# Recall (Macro): 0.8185
# Recall (Weighted): 0.8203
# F1 Score (Macro): 0.8191
# F1 Score (Weighted): 0.8207
#
# Generating confusion matrices...
# ==================================================
# DETAILED CLASSIFICATION REPORT - VALIDATION SET
# ==================================================
#               precision    recall  f1-score   support
#
#         high       0.81      0.74      0.77       159
#          low       0.85      0.85      0.85       147
#       medium       0.78      0.81      0.79       153
#    very high       0.85      0.93      0.89       149
#     very low       0.96      0.91      0.94       160
#
#     accuracy                           0.85       768
#    macro avg       0.85      0.85      0.85       768
# weighted avg       0.85      0.85      0.85       768
#
#
# ==================================================
# DETAILED CLASSIFICATION REPORT - TEST SET
# ==================================================
#               precision    recall  f1-score   support
#
#         high       0.77      0.76      0.77       136
#          low       0.79      0.73      0.76       153
#       medium       0.73      0.81      0.77       162
#    very high       0.92      0.87      0.90       167
#     very low       0.90      0.92      0.91       150
#
#     accuracy                           0.82       768
#    macro avg       0.82      0.82      0.82       768
# weighted avg       0.82      0.82      0.82       768
#
#
# ==================================================
# SUMMARY COMPARISON
# ==================================================
# Metric               Validation   Test
# --------------------------------------------------
# Accuracy             0.8490       0.8203
# F1 Score (Macro)     0.8487       0.8191
# F1 Score (Weighted)  0.8486       0.8207
