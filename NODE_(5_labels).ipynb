# %% [markdown]
# <a href="https://colab.research.google.com/github/mdsiam135/research/blob/main/NODE_(5_labels).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import warnings
warnings.filterwarnings('ignore')

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

class NODEModel:
    """
    Neural Oblivious Decision Ensembles (NODE) implementation
    """

    def __init__(self, input_dim, num_classes, num_layers=3, tree_depth=6, num_trees=2048,
                 learning_rate=0.001, batch_size=512):
        self.input_dim = input_dim
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.tree_depth = tree_depth
        self.num_trees = num_trees
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.model = None
        self.history = None

    def build_model(self):
        """Build the NODE model architecture"""
        inputs = layers.Input(shape=(self.input_dim,))

        # Feature preprocessing
        x = layers.Dense(128, activation='relu')(inputs)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.1)(x)

        # NODE layers (simplified implementation)
        for i in range(self.num_layers):
            # Oblivious decision tree simulation
            choice_function = layers.Dense(2**self.tree_depth, activation='sigmoid')(x)
            feature_selection = layers.Dense(self.tree_depth, activation='softmax')(x)

            # Tree ensemble
            tree_outputs = []
            for j in range(min(8, self.num_trees // (2**i + 1))):  # Reduced for computational efficiency
                tree_branch = layers.Dense(64, activation='relu')(x)
                tree_branch = layers.Dropout(0.1)(tree_branch)
                tree_outputs.append(tree_branch)

            if tree_outputs:
                x = layers.Add()(tree_outputs) if len(tree_outputs) > 1 else tree_outputs[0]

            x = layers.Dense(128, activation='relu')(x)
            x = layers.BatchNormalization()(x)
            x = layers.Dropout(0.1)(x)

        # Final classification layer
        outputs = layers.Dense(self.num_classes, activation='softmax')(x)

        self.model = keras.Model(inputs=inputs, outputs=outputs)

        # Compile model
        self.model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=self.learning_rate),
            loss='sparse_categorical_crossentropy',
            metrics=['accuracy']
        )

        return self.model

    def train(self, X_train, y_train, X_val, y_val, epochs=100, verbose=1):
        """Train the NODE model"""
        if self.model is None:
            self.build_model()

        # Callbacks
        early_stopping = keras.callbacks.EarlyStopping(
            monitor='val_loss', patience=15, restore_best_weights=True
        )

        reduce_lr = keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6
        )

        # Train model
        self.history = self.model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=epochs,
            batch_size=self.batch_size,
            callbacks=[early_stopping, reduce_lr],
            verbose=verbose
        )

        return self.history

    def predict(self, X):
        """Make predictions"""
        return self.model.predict(X)

    def predict_classes(self, X):
        """Predict class labels"""
        predictions = self.predict(X)
        return np.argmax(predictions, axis=1)

def load_and_preprocess_data():
    """Load and preprocess the CSV files"""
    print("Loading data...")

    # Load datasets
    train_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/train.csv')
    val_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/validation.csv')
    test_df = pd.read_csv('/content/drive/MyDrive/Yearbook of Agricultural Statistics/test.csv')

    print(f"Train shape: {train_df.shape}")
    print(f"Validation shape: {val_df.shape}")
    print(f"Test shape: {test_df.shape}")

    return train_df, val_df, test_df

def create_quantile_labels(df, target_col='Production (M.Ton)'):
    """Create quantile-based labels for production"""
    print("Creating quantile-based labels...")

    # Calculate quantiles
    quantiles = df[target_col].quantile([0.2, 0.4, 0.6, 0.8]).values
    print(f"Quantile thresholds: {quantiles}")

    # Create labels
    def get_label(value):
        if value <= quantiles[0]:
            return 0  # Very Low
        elif value <= quantiles[1]:
            return 1  # Low
        elif value <= quantiles[2]:
            return 2  # Medium
        elif value <= quantiles[3]:
            return 3  # High
        else:
            return 4  # Very High

    labels = df[target_col].apply(get_label)

    # Print label distribution
    label_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    print("Label distribution:")
    for i, name in enumerate(label_names):
        count = (labels == i).sum()
        print(f"{name}: {count} ({count/len(labels)*100:.1f}%)")

    return labels, quantiles

def preprocess_features(train_df, val_df, test_df, target_col='Production (M.Ton)'):
    """Preprocess features and prepare data for training"""
    print("Preprocessing features...")

    # Separate features and target
    feature_cols = [col for col in train_df.columns if col != target_col]

    X_train = train_df[feature_cols].copy()
    X_val = val_df[feature_cols].copy()
    X_test = test_df[feature_cols].copy()

    # Create labels
    y_train, train_quantiles = create_quantile_labels(train_df, target_col)

    # Use train quantiles for validation and test sets
    def apply_train_quantiles(df, quantiles, target_col):
        def get_label(value):
            if value <= quantiles[0]:
                return 0
            elif value <= quantiles[1]:
                return 1
            elif value <= quantiles[2]:
                return 2
            elif value <= quantiles[3]:
                return 3
            else:
                return 4
        return df[target_col].apply(get_label)

    y_val = apply_train_quantiles(val_df, train_quantiles, target_col)
    y_test = apply_train_quantiles(test_df, train_quantiles, target_col)

    # Handle missing values
    X_train = X_train.fillna(X_train.mean())
    X_val = X_val.fillna(X_train.mean())  # Use train mean for validation
    X_test = X_test.fillna(X_train.mean())  # Use train mean for test

    # Scale features
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    print(f"Feature dimensions: {X_train_scaled.shape[1]}")
    print(f"Number of classes: {len(np.unique(y_train))}")

    return (X_train_scaled, y_train, X_val_scaled, y_val,
            X_test_scaled, y_test, scaler, train_quantiles)

def calculate_metrics(y_true, y_pred, dataset_name=""):
    """Calculate comprehensive classification metrics"""
    print(f"\n{dataset_name} Classification Metrics:")
    print("-" * 50)

    # Basic metrics
    accuracy = accuracy_score(y_true, y_pred)
    precision_macro = precision_score(y_true, y_pred, average='macro')
    precision_weighted = precision_score(y_true, y_pred, average='weighted')
    recall_macro = recall_score(y_true, y_pred, average='macro')
    recall_weighted = recall_score(y_true, y_pred, average='weighted')
    f1_macro = f1_score(y_true, y_pred, average='macro')
    f1_weighted = f1_score(y_true, y_pred, average='weighted')

    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision (Macro): {precision_macro:.4f}")
    print(f"Precision (Weighted): {precision_weighted:.4f}")
    print(f"Recall (Macro): {recall_macro:.4f}")
    print(f"Recall (Weighted): {recall_weighted:.4f}")
    print(f"F1 Score (Macro): {f1_macro:.4f}")
    print(f"F1 Score (Weighted): {f1_weighted:.4f}")

    # Detailed classification report
    print(f"\nDetailed Classification Report ({dataset_name}):")
    class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    print(classification_report(y_true, y_pred, target_names=class_names))

    return {
        'accuracy': accuracy,
        'precision_macro': precision_macro,
        'precision_weighted': precision_weighted,
        'recall_macro': recall_macro,
        'recall_weighted': recall_weighted,
        'f1_macro': f1_macro,
        'f1_weighted': f1_weighted
    }

def plot_confusion_matrix(y_true, y_pred, dataset_name="", figsize=(6, 4)):
    """Plot confusion matrix"""
    plt.figure(figsize=figsize)

    # Create confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    class_names = ['Very Low', 'Low', 'Medium', 'High', 'Very High']

    # Plot heatmap
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix - {dataset_name}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

    return cm

def plot_training_history(history, metric='accuracy'):
    """Plot training and validation metrics"""
    plt.figure(figsize=(12, 4))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history[metric], label=f'Training {metric.title()}')
    plt.plot(history.history[f'val_{metric}'], label=f'Validation {metric.title()}')
    plt.title(f'Model {metric.title()}')
    plt.xlabel('Epoch')
    plt.ylabel(metric.title())
    plt.legend()
    plt.grid(True)

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

def main():
    """Main execution function"""
    print("NODE (Neural Oblivious Decision Ensembles) for Agricultural Production Classification")
    print("=" * 80)

    # Load and preprocess data
    train_df, val_df, test_df = load_and_preprocess_data()

    # Preprocess features
    (X_train, y_train, X_val, y_val,
     X_test, y_test, scaler, quantiles) = preprocess_features(train_df, val_df, test_df)

    # Initialize and build NODE model
    print("\nInitializing NODE model...")
    node_model = NODEModel(
        input_dim=X_train.shape[1],
        num_classes=5,
        num_layers=3,
        tree_depth=6,
        num_trees=1024,  # Reduced for computational efficiency
        learning_rate=0.001,
        batch_size=256
    )

    # Build model
    model = node_model.build_model()
    print(f"Model built with {model.count_params()} parameters")

    # Train model
    print("\nTraining NODE model...")
    history = node_model.train(
        X_train, y_train,
        X_val, y_val,
        epochs=100,
        verbose=1
    )

    # Plot training history
    print("\nPlotting training history...")
    plot_training_history(history)

    # Make predictions
    print("\nMaking predictions...")

    # Validation predictions
    val_pred_proba = node_model.predict(X_val)
    val_pred = np.argmax(val_pred_proba, axis=1)

    # Test predictions
    test_pred_proba = node_model.predict(X_test)
    test_pred = np.argmax(test_pred_proba, axis=1)

    # Calculate metrics
    val_metrics = calculate_metrics(y_val, val_pred, "Validation")
    test_metrics = calculate_metrics(y_test, test_pred, "Test")

    # Plot confusion matrices
    print("\nGenerating confusion matrices...")
    val_cm = plot_confusion_matrix(y_val, val_pred, "Validation Set")
    test_cm = plot_confusion_matrix(y_test, test_pred, "Test Set")

    # Summary results
    print("\n" + "="*80)
    print("FINAL RESULTS SUMMARY")
    print("="*80)
    print(f"Validation Accuracy: {val_metrics['accuracy']:.4f}")
    print(f"Validation Macro F1: {val_metrics['f1_macro']:.4f}")
    print(f"Validation Weighted F1: {val_metrics['f1_weighted']:.4f}")
    print()
    print(f"Test Accuracy: {test_metrics['accuracy']:.4f}")
    print(f"Test Macro F1: {test_metrics['f1_macro']:.4f}")
    print(f"Test Weighted F1: {test_metrics['f1_weighted']:.4f}")

    # Quantile information
    print(f"\nQuantile Thresholds Used:")
    labels = ['Very Low', 'Low', 'Medium', 'High', 'Very High']
    print(f"Very Low: ≤ {quantiles[0]:.3f}")
    print(f"Low: {quantiles[0]:.3f} - {quantiles[1]:.3f}")
    print(f"Medium: {quantiles[1]:.3f} - {quantiles[2]:.3f}")
    print(f"High: {quantiles[2]:.3f} - {quantiles[3]:.3f}")
    print(f"Very High: > {quantiles[3]:.3f}")

    return node_model, val_metrics, test_metrics, history

# Run the main function
if __name__ == "__main__":
    # Make sure you have the CSV files in the same directory
    # train.csv, validation.csv, test.csv

    try:
        model, val_metrics, test_metrics, history = main()
        print("\nModel training and evaluation completed successfully!")

    except FileNotFoundError as e:
        print(f"Error: {e}")
        print("Please make sure you have the following CSV files in the current directory:")
        print("- train.csv")
        print("- validation.csv")
        print("- test.csv")

    except Exception as e:
        print(f"An error occurred: {e}")
        print("Please check your data format and try again.")
# Out:
# NODE (Neural Oblivious Decision Ensembles) for Agricultural Production Classification
# ================================================================================
# Loading data...
# Train shape: (3584, 84)
# Validation shape: (768, 84)
# Test shape: (768, 84)
# Preprocessing features...
# Creating quantile-based labels...
# Quantile thresholds: [ 550.2   1447.52  3064.522 6362.6  ]
# Label distribution:
# Very Low: 717 (20.0%)
# Low: 717 (20.0%)
# Medium: 716 (20.0%)
# High: 717 (20.0%)
# Very High: 717 (20.0%)
# Feature dimensions: 83
# Number of classes: 5
#
# Initializing NODE model...
# Model built with 236549 parameters
#
# Training NODE model...
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 85ms/step - accuracy: 0.2061 - loss: 2.0901 - val_accuracy: 0.2148 - val_loss: 2.9618 - learning_rate: 0.0010
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.2847 - loss: 1.7324 - val_accuracy: 0.2982 - val_loss: 1.6447 - learning_rate: 0.0010
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.3184 - loss: 1.5674 - val_accuracy: 0.2734 - val_loss: 1.7696 - learning_rate: 0.0010
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.3689 - loss: 1.4719 - val_accuracy: 0.3516 - val_loss: 1.5318 - learning_rate: 0.0010
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4269 - loss: 1.3694 - val_accuracy: 0.4661 - val_loss: 1.3181 - learning_rate: 0.0010
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.4970 - loss: 1.2328 - val_accuracy: 0.5247 - val_loss: 1.1598 - learning_rate: 0.0010
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.5223 - loss: 1.1871 - val_accuracy: 0.5273 - val_loss: 1.0974 - learning_rate: 0.0010
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.5543 - loss: 1.0639 - val_accuracy: 0.5885 - val_loss: 1.0086 - learning_rate: 0.0010
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.5803 - loss: 1.0167 - val_accuracy: 0.6250 - val_loss: 0.9155 - learning_rate: 0.0010
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5845 - loss: 0.9841 - val_accuracy: 0.6549 - val_loss: 0.8504 - learning_rate: 0.0010
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6264 - loss: 0.8930 - val_accuracy: 0.6810 - val_loss: 0.7898 - learning_rate: 0.0010
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6456 - loss: 0.8540 - val_accuracy: 0.7031 - val_loss: 0.7503 - learning_rate: 0.0010
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.6821 - loss: 0.8129 - val_accuracy: 0.7266 - val_loss: 0.7310 - learning_rate: 0.0010
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.6773 - loss: 0.7919 - val_accuracy: 0.7383 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - accuracy: 0.7154 - loss: 0.7361 - val_accuracy: 0.7552 - val_loss: 0.6495 - learning_rate: 0.0010
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.7128 - loss: 0.7026 - val_accuracy: 0.7734 - val_loss: 0.6214 - learning_rate: 0.0010
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7348 - loss: 0.6692 - val_accuracy: 0.7930 - val_loss: 0.5880 - learning_rate: 0.0010
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7439 - loss: 0.6506 - val_accuracy: 0.8034 - val_loss: 0.5640 - learning_rate: 0.0010
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7654 - loss: 0.6189 - val_accuracy: 0.8138 - val_loss: 0.5482 - learning_rate: 0.0010
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7778 - loss: 0.5805 - val_accuracy: 0.8099 - val_loss: 0.5351 - learning_rate: 0.0010
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7690 - loss: 0.5733 - val_accuracy: 0.8164 - val_loss: 0.5367 - learning_rate: 0.0010
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7879 - loss: 0.5514 - val_accuracy: 0.8099 - val_loss: 0.5085 - learning_rate: 0.0010
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7853 - loss: 0.5374 - val_accuracy: 0.8268 - val_loss: 0.5108 - learning_rate: 0.0010
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.7946 - loss: 0.5244 - val_accuracy: 0.8203 - val_loss: 0.5398 - learning_rate: 0.0010
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8063 - loss: 0.5167 - val_accuracy: 0.8255 - val_loss: 0.5226 - learning_rate: 0.0010
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8190 - loss: 0.4862 - val_accuracy: 0.8242 - val_loss: 0.4956 - learning_rate: 0.0010
# Epoch 27/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8236 - loss: 0.4700 - val_accuracy: 0.8307 - val_loss: 0.4908 - learning_rate: 0.0010
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8221 - loss: 0.4540 - val_accuracy: 0.8255 - val_loss: 0.4931 - learning_rate: 0.0010
# Epoch 29/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8228 - loss: 0.4548 - val_accuracy: 0.8177 - val_loss: 0.4829 - learning_rate: 0.0010
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8408 - loss: 0.4200 - val_accuracy: 0.8372 - val_loss: 0.4768 - learning_rate: 0.0010
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8379 - loss: 0.4171 - val_accuracy: 0.8464 - val_loss: 0.4878 - learning_rate: 0.0010
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8415 - loss: 0.4039 - val_accuracy: 0.8438 - val_loss: 0.4866 - learning_rate: 0.0010
# Epoch 33/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8500 - loss: 0.3989 - val_accuracy: 0.8529 - val_loss: 0.4748 - learning_rate: 0.0010
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.8533 - loss: 0.3862 - val_accuracy: 0.8516 - val_loss: 0.4730 - learning_rate: 0.0010
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - accuracy: 0.8489 - loss: 0.3932 - val_accuracy: 0.8490 - val_loss: 0.4584 - learning_rate: 0.0010
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8495 - loss: 0.3983 - val_accuracy: 0.8385 - val_loss: 0.4545 - learning_rate: 0.0010
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8580 - loss: 0.3662 - val_accuracy: 0.8438 - val_loss: 0.4639 - learning_rate: 0.0010
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8526 - loss: 0.3861 - val_accuracy: 0.8424 - val_loss: 0.4722 - learning_rate: 0.0010
# Epoch 39/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8656 - loss: 0.3699 - val_accuracy: 0.8529 - val_loss: 0.4569 - learning_rate: 0.0010
# Epoch 40/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8782 - loss: 0.3446 - val_accuracy: 0.8398 - val_loss: 0.4710 - learning_rate: 0.0010
# Epoch 41/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8677 - loss: 0.3387 - val_accuracy: 0.8424 - val_loss: 0.4744 - learning_rate: 0.0010
# Epoch 42/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8852 - loss: 0.3157 - val_accuracy: 0.8424 - val_loss: 0.4594 - learning_rate: 0.0010
# Epoch 43/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8772 - loss: 0.3243 - val_accuracy: 0.8477 - val_loss: 0.4622 - learning_rate: 0.0010
# Epoch 44/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8750 - loss: 0.3226 - val_accuracy: 0.8516 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 45/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8743 - loss: 0.3087 - val_accuracy: 0.8594 - val_loss: 0.4630 - learning_rate: 0.0010
# Epoch 46/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8828 - loss: 0.3235 - val_accuracy: 0.8529 - val_loss: 0.4700 - learning_rate: 0.0010
# Epoch 47/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8963 - loss: 0.2955 - val_accuracy: 0.8477 - val_loss: 0.4661 - learning_rate: 5.0000e-04
# Epoch 48/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8865 - loss: 0.2839 - val_accuracy: 0.8516 - val_loss: 0.4636 - learning_rate: 5.0000e-04
# Epoch 49/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8856 - loss: 0.2784 - val_accuracy: 0.8581 - val_loss: 0.4590 - learning_rate: 5.0000e-04
# Epoch 50/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8852 - loss: 0.2902 - val_accuracy: 0.8555 - val_loss: 0.4494 - learning_rate: 5.0000e-04
# Epoch 51/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8959 - loss: 0.2671 - val_accuracy: 0.8477 - val_loss: 0.4575 - learning_rate: 5.0000e-04
# Epoch 52/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.8971 - loss: 0.2720 - val_accuracy: 0.8542 - val_loss: 0.4697 - learning_rate: 5.0000e-04
# Epoch 53/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9050 - loss: 0.2533 - val_accuracy: 0.8477 - val_loss: 0.4717 - learning_rate: 5.0000e-04
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9038 - loss: 0.2430 - val_accuracy: 0.8568 - val_loss: 0.4775 - learning_rate: 5.0000e-04
# Epoch 55/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9049 - loss: 0.2376 - val_accuracy: 0.8477 - val_loss: 0.4835 - learning_rate: 5.0000e-04
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.9108 - loss: 0.2367 - val_accuracy: 0.8607 - val_loss: 0.4761 - learning_rate: 5.0000e-04
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9014 - loss: 0.2476 - val_accuracy: 0.8581 - val_loss: 0.4751 - learning_rate: 5.0000e-04
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9097 - loss: 0.2318 - val_accuracy: 0.8542 - val_loss: 0.4753 - learning_rate: 5.0000e-04
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9018 - loss: 0.2452 - val_accuracy: 0.8594 - val_loss: 0.4749 - learning_rate: 5.0000e-04
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.9133 - loss: 0.2402 - val_accuracy: 0.8594 - val_loss: 0.4771 - learning_rate: 5.0000e-04
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.9017 - loss: 0.2463 - val_accuracy: 0.8607 - val_loss: 0.4778 - learning_rate: 2.5000e-04
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9189 - loss: 0.2223 - val_accuracy: 0.8581 - val_loss: 0.4743 - learning_rate: 2.5000e-04
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9118 - loss: 0.2342 - val_accuracy: 0.8581 - val_loss: 0.4726 - learning_rate: 2.5000e-04
# Epoch 64/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9070 - loss: 0.2354 - val_accuracy: 0.8581 - val_loss: 0.4775 - learning_rate: 2.5000e-04
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9101 - loss: 0.2179 - val_accuracy: 0.8555 - val_loss: 0.4828 - learning_rate: 2.5000e-04
#
# Plotting training history...
# Making predictions...
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# Validation Classification Metrics:
# --------------------------------------------------
# Accuracy: 0.8555
# Precision (Macro): 0.8546
# Precision (Weighted): 0.8550
# Recall (Macro): 0.8549
# Recall (Weighted): 0.8555
# F1 Score (Macro): 0.8546
# F1 Score (Weighted): 0.8551
#
# Detailed Classification Report (Validation):
#               precision    recall  f1-score   support
#
#     Very Low       0.94      0.95      0.94       160
#          Low       0.86      0.83      0.84       147
#       Medium       0.80      0.81      0.81       153
#         High       0.80      0.78      0.79       157
#    Very High       0.88      0.91      0.89       151
#
#     accuracy                           0.86       768
#    macro avg       0.85      0.85      0.85       768
# weighted avg       0.85      0.86      0.86       768
#
#
# Test Classification Metrics:
# --------------------------------------------------
# Accuracy: 0.8216
# Precision (Macro): 0.8217
# Precision (Weighted): 0.8234
# Recall (Macro): 0.8190
# Recall (Weighted): 0.8216
# F1 Score (Macro): 0.8195
# F1 Score (Weighted): 0.8216
#
# Detailed Classification Report (Test):
#               precision    recall  f1-score   support
#
#     Very Low       0.89      0.92      0.90       151
#          Low       0.81      0.74      0.77       151
#       Medium       0.74      0.82      0.78       163
#         High       0.77      0.74      0.75       136
#    Very High       0.91      0.87      0.89       167
#
#     accuracy                           0.82       768
#    macro avg       0.82      0.82      0.82       768
# weighted avg       0.82      0.82      0.82       768
#
#
# Generating confusion matrices...
# ================================================================================
# FINAL RESULTS SUMMARY
# ================================================================================
# Validation Accuracy: 0.8555
# Validation Macro F1: 0.8546
# Validation Weighted F1: 0.8551
#
# Test Accuracy: 0.8216
# Test Macro F1: 0.8195
# Test Weighted F1: 0.8216
#
# Quantile Thresholds Used:
# Very Low: ≤ 550.200
# Low: 550.200 - 1447.520
# Medium: 1447.520 - 3064.522
# High: 3064.522 - 6362.600
# Very High: > 6362.600
#
# Model training and evaluation completed successfully!
